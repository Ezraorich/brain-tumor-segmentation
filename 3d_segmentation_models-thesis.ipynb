# %%
import tensorflow as tf
#for gpu in tf.config.list_physical_devices("GPU")

# %%
#pip install tensorflow

# %%
#sess =  tf.compat.v1.Session(config=tf.ConfigProto(log_device_placement=True))

# %%
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 18114216941340827275
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 122355712
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 16990041573276124031
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:15:00.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]

# %%
import tensorflow as tf
print("Num of GPUs available: ", len(tf.test.gpu_device_name()))
# Out:
# Num of GPUs available:  13

# %%
import tensorflow as tf
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0

# %%
import os
import numpy as np


def load_img(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):    
        if (image_name.split('.')[1] == 'npy'):
            
            image = np.load(img_dir+image_name)
                      
            images.append(image)
    images = np.array(images)
    
    return(images)

# %%
def imageLoader(img_dir, img_list, mask_dir, mask_list, batch_size):

    L = len(img_list)

    #keras needs the generator infinite, so we will use while true  
    while True:

        batch_start = 0
        batch_end = batch_size

        while batch_start < L:
            limit = min(batch_end, L)
                       
            X = load_img(img_dir, img_list[batch_start:limit])
            Y = load_img(mask_dir, mask_list[batch_start:limit])

            yield (X,Y) #a tuple with two numpy arrays with batch_size samples     

            batch_start += batch_size   
            batch_end += batch_size

# %%
#def testLoader(img_dir, img_list, batch_size):

    #L = len(img_list)

    #keras needs the generator infinite, so we will use while true  
    #while True:

        #batch_start = 0
        #batch_end = batch_size

        #while batch_start < L:
            #limit = min(batch_end, L)
                       
            #X = load_img(img_dir, img_list[batch_start:limit])
            #Y = load_img(mask_dir, mask_list[batch_start:limit])

            #yield (X,Y) #a tuple with two numpy arrays with batch_size samples     
            #yield(X)
            #batch_start += batch_size   
            #batch_end += batch_size

# %%
from matplotlib import pyplot as plt
import random

train_img_dir = "/home/passion/Documents/dockerfiles/brats_split_75-25/train/images/"
train_mask_dir = "/home/passion/Documents/dockerfiles/brats_split_75-25/train/masks/"
train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

batch_size = 1

train_img_datagen = imageLoader(train_img_dir, train_img_list, 
                                train_mask_dir, train_mask_list, batch_size)

# %%
img, msk = train_img_datagen.__next__()


img_num = random.randint(0,img.shape[0]-1)
test_img=img[img_num]
test_mask=msk[img_num]
test_mask=np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
# @author: Sreenivas Bhattiprolu
# Code to train batches of cropped BraTS 2020 images using 3D U-net.

# %%
import keras

# %%
import os
import numpy as np
#from custom_datagen import imageLoader
import tensorflow as tf
import keras
from matplotlib import pyplot as plt
import glob
import random

# %%
train_img_dir = "/home/passion/Documents/dockerfiles/brats_split_75-25/train/images/"
train_mask_dir = "/home/passion/Documents/dockerfiles/brats_split_75-25/train/masks/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

num_images = len(os.listdir(train_img_dir))

img_num = random.randint(0,num_images-1)
test_img = np.load(train_img_dir+img_list[img_num])
test_mask = np.load(train_mask_dir+msk_list[img_num])
test_mask = np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import pandas as pd
columns = ['0','1', '2', '3']
df = pd.DataFrame(columns=columns)
train_mask_list = sorted(glob.glob('/home/passion/Documents/dockerfiles/brats_split_75-25/train/masks/*.npy'))
for img in range(len(train_mask_list)):
    #print(img)
    temp_image=np.load(train_mask_list[img])
    temp_image = np.argmax(temp_image, axis=3)
    val, counts = np.unique(temp_image, return_counts=True)
    zipped = zip(columns, counts)
    conts_dict = dict(zipped)
    
    df = df.append(conts_dict, ignore_index=True)
    #pd.concat([pd.DataFrame([i], columns=['A']) for i in range(5)],ignore_index=True)
    #df = pd.concat(conts_dict, ignore_index=True)

label_0 = df['0'].sum()
label_1 = df['1'].sum()
label_2 = df['1'].sum()
label_3 = df['3'].sum()
total_labels = label_0 + label_1 + label_2 + label_3
n_classes = 4

# %%
wt0 = round((total_labels/(n_classes*label_0)), 2) #round to 2 decimals
wt1 = round((total_labels/(n_classes*label_1)), 2)
wt2 = round((total_labels/(n_classes*label_2)), 2)
wt3 = round((total_labels/(n_classes*label_3)), 2)

# %%
print(wt0, wt1, wt2, wt3)
# Out:
# 0.26 22.53 22.53 26.21

# %%
train_img_dir = "/home/passion/Documents/dockerfiles/brats_split_75-25/train/images/"
train_mask_dir = "/home/passion/Documents/dockerfiles/brats_split_75-25/train/masks/"

val_img_dir = "/home/passion/Documents/dockerfiles/brats_split_75-25/val/images/"
val_mask_dir = "/home/passion/Documents/dockerfiles/brats_split_75-25/val/masks/"

train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

val_img_list=os.listdir(val_img_dir)
val_mask_list = os.listdir(val_mask_dir)

# %%
batch_size = 1

train_img_datagen = imageLoader(train_img_dir, train_img_list, 
                                train_mask_dir, train_mask_list, batch_size)

val_img_datagen = imageLoader(val_img_dir, val_img_list,val_mask_dir, val_mask_list,  batch_size)

# %%
img, msk = train_img_datagen.__next__()

img_num = random.randint(0,img.shape[0]-1)
test_img=img[img_num]
test_mask=msk[img_num]
test_mask=np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
test_img.shape
# Out:
# (128, 128, 128, 3)

# %%
import keras

# %%
#!pip3 install -U segmentation-models-3D

# %%
#keras_applications.__version__
#keras_preprocessing.__version__

# %%
import tensorflow as tf
#from tensorflow import keras
#import tensorflow.keras.backend
import segmentation_models as sm
# Out:
# Segmentation Models: using `keras` framework.

# %%
from tensorflow import keras
wt0, wt1, wt2, wt3 = 0.25,0.25,0.25,0.25
import segmentation_models_3D as sm
from tensorflow.keras.optimizers import Adam
dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1, wt2, wt3])) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

#metrics = ['accuracy', sm.metrics.IOUScore(threshold=0.5)]
metrics = ['accuracy', sm.metrics.IOUScore]

LR = 0.0001
#optim = keras.optimizers.Adam(LR)
optim = Adam(learning_rate=0.001, decay=1e-6)
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
import segmentation_models_3D as sm

# %%
model5 = sm.Unet('resnet34',classes=4, input_shape=(128, 128, 128, 3), encoder_weights=None)

# %%
import sys
sys.executable
# Out:
# '/usr/bin/python3'

# %%
import tensorflow as tf
from tensorflow import keras

# %%
#pip install tf-nightly

# %%
from tensorflow.keras.models import Sequential
from keras.models import Sequential
tf.compat.v1.enable_eager_execution()
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
from keras.models import Model
from tensorflow.keras.layers import Input, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, BatchNormalization, Dropout, Lambda
#from keras.optimizers import Adam
from tensorflow.keras.metrics import MeanIoU

kernel_initializer =  'he_uniform'

# %%
print(model5.summary())
print(model5.input_shape)
print(model5.output_shape)
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, 128, 128, 1  0           []
#                                 28, 3)]
#
#  bn_data (BatchNormalization)   (None, 128, 128, 12  9           ['data[0][0]']
#                                 8, 3)
#
#  zero_padding3d_87 (ZeroPadding  (None, 134, 134, 13  0          ['bn_data[0][0]']
#  3D)                            4, 3)
#
#  conv0 (Conv3D)                 (None, 64, 64, 64,   65856       ['zero_padding3d_87[0][0]']
#                                 64)
#
#  bn0 (BatchNormalization)       (None, 64, 64, 64,   256         ['conv0[0][0]']
#                                 64)
#
#  relu0 (Activation)             (None, 64, 64, 64,   0           ['bn0[0][0]']
#                                 64)
#
#  zero_padding3d_88 (ZeroPadding  (None, 66, 66, 66,   0          ['relu0[0][0]']
#  3D)                            64)
#
#  pooling0 (MaxPooling3D)        (None, 32, 32, 32,   0           ['zero_padding3d_88[0][0]']
#                                 64)
#
#  stage1_unit1_bn1 (BatchNormali  (None, 32, 32, 32,   256        ['pooling0[0][0]']
#  zation)                        64)
#
#  stage1_unit1_relu1 (Activation  (None, 32, 32, 32,   0          ['stage1_unit1_bn1[0][0]']
#  )                              64)
#
#  zero_padding3d_89 (ZeroPadding  (None, 34, 34, 34,   0          ['stage1_unit1_relu1[0][0]']
#  3D)                            64)
#
#  stage1_unit1_conv1 (Conv3D)    (None, 32, 32, 32,   110592      ['zero_padding3d_89[0][0]']
#                                 64)
#
#  stage1_unit1_bn2 (BatchNormali  (None, 32, 32, 32,   256        ['stage1_unit1_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit1_relu2 (Activation  (None, 32, 32, 32,   0          ['stage1_unit1_bn2[0][0]']
#  )                              64)
#
#  zero_padding3d_90 (ZeroPadding  (None, 34, 34, 34,   0          ['stage1_unit1_relu2[0][0]']
#  3D)                            64)
#
#  stage1_unit1_conv2 (Conv3D)    (None, 32, 32, 32,   110592      ['zero_padding3d_90[0][0]']
#                                 64)
#
#  stage1_unit1_sc (Conv3D)       (None, 32, 32, 32,   4096        ['stage1_unit1_relu1[0][0]']
#                                 64)
#
#  add_48 (Add)                   (None, 32, 32, 32,   0           ['stage1_unit1_conv2[0][0]',
#                                 64)                               'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, 32, 32, 32,   256        ['add_48[0][0]']
#  zation)                        64)
#
#  stage1_unit2_relu1 (Activation  (None, 32, 32, 32,   0          ['stage1_unit2_bn1[0][0]']
#  )                              64)
#
#  zero_padding3d_91 (ZeroPadding  (None, 34, 34, 34,   0          ['stage1_unit2_relu1[0][0]']
#  3D)                            64)
#
#  stage1_unit2_conv1 (Conv3D)    (None, 32, 32, 32,   110592      ['zero_padding3d_91[0][0]']
#                                 64)
#
#  stage1_unit2_bn2 (BatchNormali  (None, 32, 32, 32,   256        ['stage1_unit2_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit2_relu2 (Activation  (None, 32, 32, 32,   0          ['stage1_unit2_bn2[0][0]']
#  )                              64)
#
#  zero_padding3d_92 (ZeroPadding  (None, 34, 34, 34,   0          ['stage1_unit2_relu2[0][0]']
#  3D)                            64)
#
#  stage1_unit2_conv2 (Conv3D)    (None, 32, 32, 32,   110592      ['zero_padding3d_92[0][0]']
#                                 64)
#
#  add_49 (Add)                   (None, 32, 32, 32,   0           ['stage1_unit2_conv2[0][0]',
#                                 64)                               'add_48[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, 32, 32, 32,   256        ['add_49[0][0]']
#  zation)                        64)
#
#  stage1_unit3_relu1 (Activation  (None, 32, 32, 32,   0          ['stage1_unit3_bn1[0][0]']
#  )                              64)
#
#  zero_padding3d_93 (ZeroPadding  (None, 34, 34, 34,   0          ['stage1_unit3_relu1[0][0]']
#  3D)                            64)
#
#  stage1_unit3_conv1 (Conv3D)    (None, 32, 32, 32,   110592      ['zero_padding3d_93[0][0]']
#                                 64)
#
#  stage1_unit3_bn2 (BatchNormali  (None, 32, 32, 32,   256        ['stage1_unit3_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit3_relu2 (Activation  (None, 32, 32, 32,   0          ['stage1_unit3_bn2[0][0]']
#  )                              64)
#
#  zero_padding3d_94 (ZeroPadding  (None, 34, 34, 34,   0          ['stage1_unit3_relu2[0][0]']
#  3D)                            64)
#
#  stage1_unit3_conv2 (Conv3D)    (None, 32, 32, 32,   110592      ['zero_padding3d_94[0][0]']
#                                 64)
#
#  add_50 (Add)                   (None, 32, 32, 32,   0           ['stage1_unit3_conv2[0][0]',
#                                 64)                               'add_49[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, 32, 32, 32,   256        ['add_50[0][0]']
#  zation)                        64)
#
#  stage2_unit1_relu1 (Activation  (None, 32, 32, 32,   0          ['stage2_unit1_bn1[0][0]']
#  )                              64)
#
#  zero_padding3d_95 (ZeroPadding  (None, 34, 34, 34,   0          ['stage2_unit1_relu1[0][0]']
#  3D)                            64)
#
#  stage2_unit1_conv1 (Conv3D)    (None, 16, 16, 16,   221184      ['zero_padding3d_95[0][0]']
#                                 128)
#
#  stage2_unit1_bn2 (BatchNormali  (None, 16, 16, 16,   512        ['stage2_unit1_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit1_relu2 (Activation  (None, 16, 16, 16,   0          ['stage2_unit1_bn2[0][0]']
#  )                              128)
#
#  zero_padding3d_96 (ZeroPadding  (None, 18, 18, 18,   0          ['stage2_unit1_relu2[0][0]']
#  3D)                            128)
#
#  stage2_unit1_conv2 (Conv3D)    (None, 16, 16, 16,   442368      ['zero_padding3d_96[0][0]']
#                                 128)
#
#  stage2_unit1_sc (Conv3D)       (None, 16, 16, 16,   8192        ['stage2_unit1_relu1[0][0]']
#                                 128)
#
#  add_51 (Add)                   (None, 16, 16, 16,   0           ['stage2_unit1_conv2[0][0]',
#                                 128)                              'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, 16, 16, 16,   512        ['add_51[0][0]']
#  zation)                        128)
#
#  stage2_unit2_relu1 (Activation  (None, 16, 16, 16,   0          ['stage2_unit2_bn1[0][0]']
#  )                              128)
#
#  zero_padding3d_97 (ZeroPadding  (None, 18, 18, 18,   0          ['stage2_unit2_relu1[0][0]']
#  3D)                            128)
#
#  stage2_unit2_conv1 (Conv3D)    (None, 16, 16, 16,   442368      ['zero_padding3d_97[0][0]']
#                                 128)
#
#  stage2_unit2_bn2 (BatchNormali  (None, 16, 16, 16,   512        ['stage2_unit2_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit2_relu2 (Activation  (None, 16, 16, 16,   0          ['stage2_unit2_bn2[0][0]']
#  )                              128)
#
#  zero_padding3d_98 (ZeroPadding  (None, 18, 18, 18,   0          ['stage2_unit2_relu2[0][0]']
#  3D)                            128)
#
#  stage2_unit2_conv2 (Conv3D)    (None, 16, 16, 16,   442368      ['zero_padding3d_98[0][0]']
#                                 128)
#
#  add_52 (Add)                   (None, 16, 16, 16,   0           ['stage2_unit2_conv2[0][0]',
#                                 128)                              'add_51[0][0]']
#
#  stage2_unit3_bn1 (BatchNormali  (None, 16, 16, 16,   512        ['add_52[0][0]']
#  zation)                        128)
#
#  stage2_unit3_relu1 (Activation  (None, 16, 16, 16,   0          ['stage2_unit3_bn1[0][0]']
#  )                              128)
#
#  zero_padding3d_99 (ZeroPadding  (None, 18, 18, 18,   0          ['stage2_unit3_relu1[0][0]']
#  3D)                            128)
#
#  stage2_unit3_conv1 (Conv3D)    (None, 16, 16, 16,   442368      ['zero_padding3d_99[0][0]']
#                                 128)
#
#  stage2_unit3_bn2 (BatchNormali  (None, 16, 16, 16,   512        ['stage2_unit3_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit3_relu2 (Activation  (None, 16, 16, 16,   0          ['stage2_unit3_bn2[0][0]']
#  )                              128)
#
#  zero_padding3d_100 (ZeroPaddin  (None, 18, 18, 18,   0          ['stage2_unit3_relu2[0][0]']
#  g3D)                           128)
#
#  stage2_unit3_conv2 (Conv3D)    (None, 16, 16, 16,   442368      ['zero_padding3d_100[0][0]']
#                                 128)
#
#  add_53 (Add)                   (None, 16, 16, 16,   0           ['stage2_unit3_conv2[0][0]',
#                                 128)                              'add_52[0][0]']
#
#  stage2_unit4_bn1 (BatchNormali  (None, 16, 16, 16,   512        ['add_53[0][0]']
#  zation)                        128)
#
#  stage2_unit4_relu1 (Activation  (None, 16, 16, 16,   0          ['stage2_unit4_bn1[0][0]']
#  )                              128)
#
#  zero_padding3d_101 (ZeroPaddin  (None, 18, 18, 18,   0          ['stage2_unit4_relu1[0][0]']
#  g3D)                           128)
#
#  stage2_unit4_conv1 (Conv3D)    (None, 16, 16, 16,   442368      ['zero_padding3d_101[0][0]']
#                                 128)
#
#  stage2_unit4_bn2 (BatchNormali  (None, 16, 16, 16,   512        ['stage2_unit4_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit4_relu2 (Activation  (None, 16, 16, 16,   0          ['stage2_unit4_bn2[0][0]']
#  )                              128)
#
#  zero_padding3d_102 (ZeroPaddin  (None, 18, 18, 18,   0          ['stage2_unit4_relu2[0][0]']
#  g3D)                           128)
#
#  stage2_unit4_conv2 (Conv3D)    (None, 16, 16, 16,   442368      ['zero_padding3d_102[0][0]']
#                                 128)
#
#  add_54 (Add)                   (None, 16, 16, 16,   0           ['stage2_unit4_conv2[0][0]',
#                                 128)                              'add_53[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, 16, 16, 16,   512        ['add_54[0][0]']
#  zation)                        128)
#
#  stage3_unit1_relu1 (Activation  (None, 16, 16, 16,   0          ['stage3_unit1_bn1[0][0]']
#  )                              128)
#
#  zero_padding3d_103 (ZeroPaddin  (None, 18, 18, 18,   0          ['stage3_unit1_relu1[0][0]']
#  g3D)                           128)
#
#  stage3_unit1_conv1 (Conv3D)    (None, 8, 8, 8, 256  884736      ['zero_padding3d_103[0][0]']
#                                 )
#
#  stage3_unit1_bn2 (BatchNormali  (None, 8, 8, 8, 256  1024       ['stage3_unit1_conv1[0][0]']
#  zation)                        )
#
#  stage3_unit1_relu2 (Activation  (None, 8, 8, 8, 256  0          ['stage3_unit1_bn2[0][0]']
#  )                              )
#
#  zero_padding3d_104 (ZeroPaddin  (None, 10, 10, 10,   0          ['stage3_unit1_relu2[0][0]']
#  g3D)                           256)
#
#  stage3_unit1_conv2 (Conv3D)    (None, 8, 8, 8, 256  1769472     ['zero_padding3d_104[0][0]']
#                                 )
#
#  stage3_unit1_sc (Conv3D)       (None, 8, 8, 8, 256  32768       ['stage3_unit1_relu1[0][0]']
#                                 )
#  add_55 (Add)                   (None, 8, 8, 8, 256  0           ['stage3_unit1_conv2[0][0]',
#                                 )                                 'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, 8, 8, 8, 256  1024       ['add_55[0][0]']
#  zation)                        )
#
#  stage3_unit2_relu1 (Activation  (None, 8, 8, 8, 256  0          ['stage3_unit2_bn1[0][0]']
#  )                              )
#
#  zero_padding3d_105 (ZeroPaddin  (None, 10, 10, 10,   0          ['stage3_unit2_relu1[0][0]']
#  g3D)                           256)
#
#  stage3_unit2_conv1 (Conv3D)    (None, 8, 8, 8, 256  1769472     ['zero_padding3d_105[0][0]']
#                                 )
#
#  stage3_unit2_bn2 (BatchNormali  (None, 8, 8, 8, 256  1024       ['stage3_unit2_conv1[0][0]']
#  zation)                        )
#
#  stage3_unit2_relu2 (Activation  (None, 8, 8, 8, 256  0          ['stage3_unit2_bn2[0][0]']
#  )                              )
#
#  zero_padding3d_106 (ZeroPaddin  (None, 10, 10, 10,   0          ['stage3_unit2_relu2[0][0]']
#  g3D)                           256)
#
#  stage3_unit2_conv2 (Conv3D)    (None, 8, 8, 8, 256  1769472     ['zero_padding3d_106[0][0]']
#                                 )
#
#  add_56 (Add)                   (None, 8, 8, 8, 256  0           ['stage3_unit2_conv2[0][0]',
#                                 )                                 'add_55[0][0]']
#
#  stage3_unit3_bn1 (BatchNormali  (None, 8, 8, 8, 256  1024       ['add_56[0][0]']
#  zation)                        )
#
#  stage3_unit3_relu1 (Activation  (None, 8, 8, 8, 256  0          ['stage3_unit3_bn1[0][0]']
#  )                              )
#
#  zero_padding3d_107 (ZeroPaddin  (None, 10, 10, 10,   0          ['stage3_unit3_relu1[0][0]']
#  g3D)                           256)
#
#  stage3_unit3_conv1 (Conv3D)    (None, 8, 8, 8, 256  1769472     ['zero_padding3d_107[0][0]']
#                                 )
#
#  stage3_unit3_bn2 (BatchNormali  (None, 8, 8, 8, 256  1024       ['stage3_unit3_conv1[0][0]']
#  zation)                        )
#
#  stage3_unit3_relu2 (Activation  (None, 8, 8, 8, 256  0          ['stage3_unit3_bn2[0][0]']
#  )                              )
#
#  zero_padding3d_108 (ZeroPaddin  (None, 10, 10, 10,   0          ['stage3_unit3_relu2[0][0]']
#  g3D)                           256)
#
#  stage3_unit3_conv2 (Conv3D)    (None, 8, 8, 8, 256  1769472     ['zero_padding3d_108[0][0]']
#                                 )
#
#  add_57 (Add)                   (None, 8, 8, 8, 256  0           ['stage3_unit3_conv2[0][0]',
#                                 )                                 'add_56[0][0]']
#
#  stage3_unit4_bn1 (BatchNormali  (None, 8, 8, 8, 256  1024       ['add_57[0][0]']
#  zation)                        )
#
#  stage3_unit4_relu1 (Activation  (None, 8, 8, 8, 256  0          ['stage3_unit4_bn1[0][0]']
#  )                              )
#
#  zero_padding3d_109 (ZeroPaddin  (None, 10, 10, 10,   0          ['stage3_unit4_relu1[0][0]']
#  g3D)                           256)
#
#  stage3_unit4_conv1 (Conv3D)    (None, 8, 8, 8, 256  1769472     ['zero_padding3d_109[0][0]']
#                                 )
#
#  stage3_unit4_bn2 (BatchNormali  (None, 8, 8, 8, 256  1024       ['stage3_unit4_conv1[0][0]']
#  zation)                        )
#
#  stage3_unit4_relu2 (Activation  (None, 8, 8, 8, 256  0          ['stage3_unit4_bn2[0][0]']
#  )                              )
#
#  zero_padding3d_110 (ZeroPaddin  (None, 10, 10, 10,   0          ['stage3_unit4_relu2[0][0]']
#  g3D)                           256)
#
#  stage3_unit4_conv2 (Conv3D)    (None, 8, 8, 8, 256  1769472     ['zero_padding3d_110[0][0]']
#                                 )
#
#  add_58 (Add)                   (None, 8, 8, 8, 256  0           ['stage3_unit4_conv2[0][0]',
#                                 )                                 'add_57[0][0]']
#
#  stage3_unit5_bn1 (BatchNormali  (None, 8, 8, 8, 256  1024       ['add_58[0][0]']
#  zation)                        )
#
#  stage3_unit5_relu1 (Activation  (None, 8, 8, 8, 256  0          ['stage3_unit5_bn1[0][0]']
#  )                              )
#
#  zero_padding3d_111 (ZeroPaddin  (None, 10, 10, 10,   0          ['stage3_unit5_relu1[0][0]']
#  g3D)                           256)
#
#  stage3_unit5_conv1 (Conv3D)    (None, 8, 8, 8, 256  1769472     ['zero_padding3d_111[0][0]']
#                                 )
#
#  stage3_unit5_bn2 (BatchNormali  (None, 8, 8, 8, 256  1024       ['stage3_unit5_conv1[0][0]']
#  zation)                        )
#
#  stage3_unit5_relu2 (Activation  (None, 8, 8, 8, 256  0          ['stage3_unit5_bn2[0][0]']
#  )                              )
#
#  zero_padding3d_112 (ZeroPaddin  (None, 10, 10, 10,   0          ['stage3_unit5_relu2[0][0]']
#  g3D)                           256)
#
#  stage3_unit5_conv2 (Conv3D)    (None, 8, 8, 8, 256  1769472     ['zero_padding3d_112[0][0]']
#                                 )
#
#  add_59 (Add)                   (None, 8, 8, 8, 256  0           ['stage3_unit5_conv2[0][0]',
#                                 )                                 'add_58[0][0]']
#
#  stage3_unit6_bn1 (BatchNormali  (None, 8, 8, 8, 256  1024       ['add_59[0][0]']
#  zation)                        )
#
#  stage3_unit6_relu1 (Activation  (None, 8, 8, 8, 256  0          ['stage3_unit6_bn1[0][0]']
#  )                              )
#
#  zero_padding3d_113 (ZeroPaddin  (None, 10, 10, 10,   0          ['stage3_unit6_relu1[0][0]']
#  g3D)                           256)
#
#  stage3_unit6_conv1 (Conv3D)    (None, 8, 8, 8, 256  1769472     ['zero_padding3d_113[0][0]']
#                                 )
#
#  stage3_unit6_bn2 (BatchNormali  (None, 8, 8, 8, 256  1024       ['stage3_unit6_conv1[0][0]']
#  zation)                        )
#
#  stage3_unit6_relu2 (Activation  (None, 8, 8, 8, 256  0          ['stage3_unit6_bn2[0][0]']
#  )                              )
#
#  zero_padding3d_114 (ZeroPaddin  (None, 10, 10, 10,   0          ['stage3_unit6_relu2[0][0]']
#  g3D)                           256)
#
#  stage3_unit6_conv2 (Conv3D)    (None, 8, 8, 8, 256  1769472     ['zero_padding3d_114[0][0]']
#                                 )
#
#  add_60 (Add)                   (None, 8, 8, 8, 256  0           ['stage3_unit6_conv2[0][0]',
#                                 )                                 'add_59[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, 8, 8, 8, 256  1024       ['add_60[0][0]']
#  zation)                        )
#
#  stage4_unit1_relu1 (Activation  (None, 8, 8, 8, 256  0          ['stage4_unit1_bn1[0][0]']
#  )                              )
#
#  zero_padding3d_115 (ZeroPaddin  (None, 10, 10, 10,   0          ['stage4_unit1_relu1[0][0]']
#  g3D)                           256)
#
#  stage4_unit1_conv1 (Conv3D)    (None, 4, 4, 4, 512  3538944     ['zero_padding3d_115[0][0]']
#                                 )
#
#  stage4_unit1_bn2 (BatchNormali  (None, 4, 4, 4, 512  2048       ['stage4_unit1_conv1[0][0]']
#  zation)                        )
#
#  stage4_unit1_relu2 (Activation  (None, 4, 4, 4, 512  0          ['stage4_unit1_bn2[0][0]']
#  )                              )
#
#  zero_padding3d_116 (ZeroPaddin  (None, 6, 6, 6, 512  0          ['stage4_unit1_relu2[0][0]']
#  g3D)                           )
#
#  stage4_unit1_conv2 (Conv3D)    (None, 4, 4, 4, 512  7077888     ['zero_padding3d_116[0][0]']
#                                 )
#
#  stage4_unit1_sc (Conv3D)       (None, 4, 4, 4, 512  131072      ['stage4_unit1_relu1[0][0]']
#                                 )
#
#  add_61 (Add)                   (None, 4, 4, 4, 512  0           ['stage4_unit1_conv2[0][0]',
#                                 )                                 'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, 4, 4, 4, 512  2048       ['add_61[0][0]']
#  zation)                        )
#
#  stage4_unit2_relu1 (Activation  (None, 4, 4, 4, 512  0          ['stage4_unit2_bn1[0][0]']
#  )                              )
#
#  zero_padding3d_117 (ZeroPaddin  (None, 6, 6, 6, 512  0          ['stage4_unit2_relu1[0][0]']
#  g3D)                           )
#
#  stage4_unit2_conv1 (Conv3D)    (None, 4, 4, 4, 512  7077888     ['zero_padding3d_117[0][0]']
#                                 )
#
#  stage4_unit2_bn2 (BatchNormali  (None, 4, 4, 4, 512  2048       ['stage4_unit2_conv1[0][0]']
#  zation)                        )
#
#  stage4_unit2_relu2 (Activation  (None, 4, 4, 4, 512  0          ['stage4_unit2_bn2[0][0]']
#  )                              )
#
#  zero_padding3d_118 (ZeroPaddin  (None, 6, 6, 6, 512  0          ['stage4_unit2_relu2[0][0]']
#  g3D)                           )
#
#  stage4_unit2_conv2 (Conv3D)    (None, 4, 4, 4, 512  7077888     ['zero_padding3d_118[0][0]']
#                                 )
#
#  add_62 (Add)                   (None, 4, 4, 4, 512  0           ['stage4_unit2_conv2[0][0]',
#                                 )                                 'add_61[0][0]']
#
#  stage4_unit3_bn1 (BatchNormali  (None, 4, 4, 4, 512  2048       ['add_62[0][0]']
#  zation)                        )
#
#  stage4_unit3_relu1 (Activation  (None, 4, 4, 4, 512  0          ['stage4_unit3_bn1[0][0]']
#  )                              )
#
#  zero_padding3d_119 (ZeroPaddin  (None, 6, 6, 6, 512  0          ['stage4_unit3_relu1[0][0]']
#  g3D)                           )
#
#  stage4_unit3_conv1 (Conv3D)    (None, 4, 4, 4, 512  7077888     ['zero_padding3d_119[0][0]']
#                                 )
#
#  stage4_unit3_bn2 (BatchNormali  (None, 4, 4, 4, 512  2048       ['stage4_unit3_conv1[0][0]']
#  zation)                        )
#
#  stage4_unit3_relu2 (Activation  (None, 4, 4, 4, 512  0          ['stage4_unit3_bn2[0][0]']
#  )                              )
#
#  zero_padding3d_120 (ZeroPaddin  (None, 6, 6, 6, 512  0          ['stage4_unit3_relu2[0][0]']
#  g3D)                           )
#
#  stage4_unit3_conv2 (Conv3D)    (None, 4, 4, 4, 512  7077888     ['zero_padding3d_120[0][0]']
#                                 )
#
#  add_63 (Add)                   (None, 4, 4, 4, 512  0           ['stage4_unit3_conv2[0][0]',
#                                 )                                 'add_62[0][0]']
#
#  bn1 (BatchNormalization)       (None, 4, 4, 4, 512  2048        ['add_63[0][0]']
#                                 )
#
#  relu1 (Activation)             (None, 4, 4, 4, 512  0           ['bn1[0][0]']
#                                 )
#
#  decoder_stage0_upsampling (UpS  (None, 8, 8, 8, 512  0          ['relu1[0][0]']
#  ampling3D)                     )
#
#  decoder_stage0_concat (Concate  (None, 8, 8, 8, 768  0          ['decoder_stage0_upsampling[0][0]
#  nate)                          )                                ',
#                                                                   'stage4_unit1_relu1[0][0]']
#
#  decoder_stage0a_conv (Conv3D)  (None, 8, 8, 8, 256  5308416     ['decoder_stage0_concat[0][0]']
#                                 )
#
#  decoder_stage0a_bn (BatchNorma  (None, 8, 8, 8, 256  1024       ['decoder_stage0a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage0a_relu (Activati  (None, 8, 8, 8, 256  0          ['decoder_stage0a_bn[0][0]']
#  on)                            )
#
#  decoder_stage0b_conv (Conv3D)  (None, 8, 8, 8, 256  1769472     ['decoder_stage0a_relu[0][0]']
#                                 )
#
#  decoder_stage0b_bn (BatchNorma  (None, 8, 8, 8, 256  1024       ['decoder_stage0b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage0b_relu (Activati  (None, 8, 8, 8, 256  0          ['decoder_stage0b_bn[0][0]']
#  on)                            )
#
#  decoder_stage1_upsampling (UpS  (None, 16, 16, 16,   0          ['decoder_stage0b_relu[0][0]']
#  ampling3D)                     256)
#
#  decoder_stage1_concat (Concate  (None, 16, 16, 16,   0          ['decoder_stage1_upsampling[0][0]
#  nate)                          384)                             ',
#                                                                   'stage3_unit1_relu1[0][0]']
#
#  decoder_stage1a_conv (Conv3D)  (None, 16, 16, 16,   1327104     ['decoder_stage1_concat[0][0]']
#                                 128)
#
#  decoder_stage1a_bn (BatchNorma  (None, 16, 16, 16,   512        ['decoder_stage1a_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1a_relu (Activati  (None, 16, 16, 16,   0          ['decoder_stage1a_bn[0][0]']
#  on)                            128)
#
#  decoder_stage1b_conv (Conv3D)  (None, 16, 16, 16,   442368      ['decoder_stage1a_relu[0][0]']
#                                 128)
#
#  decoder_stage1b_bn (BatchNorma  (None, 16, 16, 16,   512        ['decoder_stage1b_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1b_relu (Activati  (None, 16, 16, 16,   0          ['decoder_stage1b_bn[0][0]']
#  on)                            128)
#
#  decoder_stage2_upsampling (UpS  (None, 32, 32, 32,   0          ['decoder_stage1b_relu[0][0]']
#  ampling3D)                     128)
#
#  decoder_stage2_concat (Concate  (None, 32, 32, 32,   0          ['decoder_stage2_upsampling[0][0]
#  nate)                          192)                             ',
#                                                                   'stage2_unit1_relu1[0][0]']
#
#  decoder_stage2a_conv (Conv3D)  (None, 32, 32, 32,   331776      ['decoder_stage2_concat[0][0]']
#                                 64)
#
#  decoder_stage2a_bn (BatchNorma  (None, 32, 32, 32,   256        ['decoder_stage2a_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2a_relu (Activati  (None, 32, 32, 32,   0          ['decoder_stage2a_bn[0][0]']
#  on)                            64)
#
#  decoder_stage2b_conv (Conv3D)  (None, 32, 32, 32,   110592      ['decoder_stage2a_relu[0][0]']
#                                 64)
#
#  decoder_stage2b_bn (BatchNorma  (None, 32, 32, 32,   256        ['decoder_stage2b_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2b_relu (Activati  (None, 32, 32, 32,   0          ['decoder_stage2b_bn[0][0]']
#  on)                            64)
#
#  decoder_stage3_upsampling (UpS  (None, 64, 64, 64,   0          ['decoder_stage2b_relu[0][0]']
#  ampling3D)                     64)
#
#  decoder_stage3_concat (Concate  (None, 64, 64, 64,   0          ['decoder_stage3_upsampling[0][0]
#  nate)                          128)                             ',
#                                                                   'relu0[0][0]']
#
#  decoder_stage3a_conv (Conv3D)  (None, 64, 64, 64,   110592      ['decoder_stage3_concat[0][0]']
#                                 32)
#
#  decoder_stage3a_bn (BatchNorma  (None, 64, 64, 64,   128        ['decoder_stage3a_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3a_relu (Activati  (None, 64, 64, 64,   0          ['decoder_stage3a_bn[0][0]']
#  on)                            32)
#
#  decoder_stage3b_conv (Conv3D)  (None, 64, 64, 64,   27648       ['decoder_stage3a_relu[0][0]']
#                                 32)
#
#  decoder_stage3b_bn (BatchNorma  (None, 64, 64, 64,   128        ['decoder_stage3b_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3b_relu (Activati  (None, 64, 64, 64,   0          ['decoder_stage3b_bn[0][0]']
#  on)                            32)
#
#  decoder_stage4_upsampling (UpS  (None, 128, 128, 12  0          ['decoder_stage3b_relu[0][0]']
#  ampling3D)                     8, 32)
#
#  decoder_stage4a_conv (Conv3D)  (None, 128, 128, 12  13824       ['decoder_stage4_upsampling[0][0]
#                                 8, 16)                           ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 128, 128, 12  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      8, 16)
#
#  decoder_stage4a_relu (Activati  (None, 128, 128, 12  0          ['decoder_stage4a_bn[0][0]']
#  on)                            8, 16)
#
#  decoder_stage4b_conv (Conv3D)  (None, 128, 128, 12  6912        ['decoder_stage4a_relu[0][0]']
#                                 8, 16)
#
#  decoder_stage4b_bn (BatchNorma  (None, 128, 128, 12  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      8, 16)
#
#  decoder_stage4b_relu (Activati  (None, 128, 128, 12  0          ['decoder_stage4b_bn[0][0]']
#  on)                            8, 16)
#
#  final_conv (Conv3D)            (None, 128, 128, 12  1732        ['decoder_stage4b_relu[0][0]']
#                                 8, 4)
#
#  sigmoid (Activation)           (None, 128, 128, 12  0           ['final_conv[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 72,985,741
# Trainable params: 72,968,391
# Non-trainable params: 17,350
# __________________________________________________________________________________________________
# None
# (None, 128, 128, 128, 3)
# (None, 128, 128, 128, 4)

# %%
model5.compile(optimizer = 'adam', loss=total_loss, metrics=metrics)

# %%
history=model5.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=100,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )
# Out:
# Epoch 1/100
# 258/258 [==============================] - 133s 492ms/step - loss: 0.9306 - accuracy: 0.8470 - iou_score: 0.2594 - val_loss: 0.9297 - val_accuracy: 0.7520 - val_iou_score: 0.2593
# Epoch 2/100
# 258/258 [==============================] - 130s 503ms/step - loss: 0.9281 - accuracy: 0.9491 - iou_score: 0.2646 - val_loss: 0.9277 - val_accuracy: 0.9498 - val_iou_score: 0.2655
# Epoch 3/100
# 258/258 [==============================] - 131s 508ms/step - loss: 0.9276 - accuracy: 0.9520 - iou_score: 0.2669 - val_loss: 0.9276 - val_accuracy: 0.9341 - val_iou_score: 0.2647
# Epoch 4/100
# 258/258 [==============================] - 131s 507ms/step - loss: 0.9273 - accuracy: 0.9520 - iou_score: 0.2682 - val_loss: 0.9276 - val_accuracy: 0.9503 - val_iou_score: 0.2676
# Epoch 5/100
# 258/258 [==============================] - 131s 506ms/step - loss: 0.9269 - accuracy: 0.9520 - iou_score: 0.2701 - val_loss: 0.9271 - val_accuracy: 0.9503 - val_iou_score: 0.2697
# Epoch 6/100
# 258/258 [==============================] - 131s 508ms/step - loss: 0.9266 - accuracy: 0.9520 - iou_score: 0.2714 - val_loss: 0.9270 - val_accuracy: 0.9503 - val_iou_score: 0.2691
# Epoch 7/100
# 258/258 [==============================] - 130s 506ms/step - loss: 0.9264 - accuracy: 0.9520 - iou_score: 0.2724 - val_loss: 0.9274 - val_accuracy: 0.9503 - val_iou_score: 0.2690
# Epoch 8/100
# 258/258 [==============================] - 131s 507ms/step - loss: 0.9261 - accuracy: 0.9520 - iou_score: 0.2738 - val_loss: 0.9273 - val_accuracy: 0.9503 - val_iou_score: 0.2703
# Epoch 9/100
# 258/258 [==============================] - 131s 508ms/step - loss: 0.9260 - accuracy: 0.9520 - iou_score: 0.2747 - val_loss: 0.9271 - val_accuracy: 0.9503 - val_iou_score: 0.2703
# Epoch 10/100
# 258/258 [==============================] - 131s 508ms/step - loss: 0.9259 - accuracy: 0.9520 - iou_score: 0.2749 - val_loss: 0.9269 - val_accuracy: 0.9503 - val_iou_score: 0.2699
# Epoch 11/100
# 258/258 [==============================] - 131s 507ms/step - loss: 0.9261 - accuracy: 0.9520 - iou_score: 0.2742 - val_loss: 0.9270 - val_accuracy: 0.9503 - val_iou_score: 0.2713
# Epoch 12/100
# 258/258 [==============================] - 131s 507ms/step - loss: 0.9260 - accuracy: 0.9520 - iou_score: 0.2748 - val_loss: 0.9266 - val_accuracy: 0.9503 - val_iou_score: 0.2721
# Epoch 13/100
# 258/258 [==============================] - 131s 507ms/step - loss: 0.9259 - accuracy: 0.9520 - iou_score: 0.2743 - val_loss: 0.9264 - val_accuracy: 0.9503 - val_iou_score: 0.2719
# Epoch 14/100
# 258/258 [==============================] - 131s 507ms/step - loss: 0.9258 - accuracy: 0.9520 - iou_score: 0.2749 - val_loss: 0.9265 - val_accuracy: 0.9503 - val_iou_score: 0.2722
# Epoch 15/100
# 258/258 [==============================] - 131s 509ms/step - loss: 0.9258 - accuracy: 0.9520 - iou_score: 0.2751 - val_loss: 0.9267 - val_accuracy: 0.9503 - val_iou_score: 0.2720
# Epoch 16/100
# 258/258 [==============================] - 131s 508ms/step - loss: 0.9258 - accuracy: 0.9520 - iou_score: 0.2751 - val_loss: 0.9268 - val_accuracy: 0.9503 - val_iou_score: 0.2719
# Epoch 17/100
# 258/258 [==============================] - 131s 509ms/step - loss: 0.9256 - accuracy: 0.9520 - iou_score: 0.2759 - val_loss: 0.9268 - val_accuracy: 0.9503 - val_iou_score: 0.2718
# Epoch 18/100
# 258/258 [==============================] - 131s 510ms/step - loss: 0.9255 - accuracy: 0.9520 - iou_score: 0.2760 - val_loss: 0.9275 - val_accuracy: 0.9503 - val_iou_score: 0.2706
# Epoch 19/100
# 258/258 [==============================] - 131s 509ms/step - loss: 0.9255 - accuracy: 0.9520 - iou_score: 0.2761 - val_loss: 0.9268 - val_accuracy: 0.9503 - val_iou_score: 0.2715
# Epoch 20/100
# 258/258 [==============================] - 131s 508ms/step - loss: 0.9255 - accuracy: 0.9520 - iou_score: 0.2762 - val_loss: 0.9269 - val_accuracy: 0.9503 - val_iou_score: 0.2713
# Epoch 21/100
# 258/258 [==============================] - 131s 508ms/step - loss: 0.9262 - accuracy: 0.9520 - iou_score: 0.2735 - val_loss: 0.9269 - val_accuracy: 0.9502 - val_iou_score: 0.2719
# Epoch 22/100
# 258/258 [==============================] - 131s 509ms/step - loss: 0.9256 - accuracy: 0.9520 - iou_score: 0.2760 - val_loss: 0.9281 - val_accuracy: 0.9503 - val_iou_score: 0.2722
# Epoch 23/100
# 258/258 [==============================] - 131s 507ms/step - loss: 0.9254 - accuracy: 0.9520 - iou_score: 0.2765 - val_loss: 0.9268 - val_accuracy: 0.9503 - val_iou_score: 0.2716
# Epoch 24/100
# 258/258 [==============================] - 131s 508ms/step - loss: 0.9253 - accuracy: 0.9520 - iou_score: 0.2767 - val_loss: 0.9268 - val_accuracy: 0.9503 - val_iou_score: 0.2715
# Epoch 25/100
# 258/258 [==============================] - 131s 509ms/step - loss: 0.9252 - accuracy: 0.9520 - iou_score: 0.2774 - val_loss: 0.9268 - val_accuracy: 0.9503 - val_iou_score: 0.2719
# Epoch 26/100
# 258/258 [==============================] - 131s 508ms/step - loss: 0.9252 - accuracy: 0.9520 - iou_score: 0.2779 - val_loss: 0.9270 - val_accuracy: 0.9503 - val_iou_score: 0.2710
# Epoch 27/100
# 258/258 [==============================] - 131s 509ms/step - loss: 0.9256 - accuracy: 0.9520 - iou_score: 0.2763 - val_loss: 0.9268 - val_accuracy: 0.9503 - val_iou_score: 0.2701
# Epoch 28/100
# 258/258 [==============================] - 131s 509ms/step - loss: 0.9254 - accuracy: 0.9520 - iou_score: 0.2764 - val_loss: 0.9275 - val_accuracy: 0.9503 - val_iou_score: 0.2693
# Epoch 29/100
# 258/258 [==============================] - 131s 509ms/step - loss: 0.9250 - accuracy: 0.9520 - iou_score: 0.2785 - val_loss: 0.9273 - val_accuracy: 0.9503 - val_iou_score: 0.2704
# Epoch 30/100
# 258/258 [==============================] - 131s 509ms/step - loss: 0.9247 - accuracy: 0.9520 - iou_score: 0.2793 - val_loss: 0.9278 - val_accuracy: 0.9503 - val_iou_score: 0.2689
# Epoch 31/100
# 258/258 [==============================] - 130s 506ms/step - loss: 0.9245 - accuracy: 0.9520 - iou_score: 0.2800 - val_loss: 0.9273 - val_accuracy: 0.9503 - val_iou_score: 0.2712
# Epoch 32/100
# 258/258 [==============================] - 132s 510ms/step - loss: 0.9242 - accuracy: 0.9520 - iou_score: 0.2815 - val_loss: 0.9283 - val_accuracy: 0.9503 - val_iou_score: 0.2694
# Epoch 33/100
# 258/258 [==============================] - 132s 510ms/step - loss: 0.9240 - accuracy: 0.9520 - iou_score: 0.2817 - val_loss: 0.9277 - val_accuracy: 0.9503 - val_iou_score: 0.2693
# Epoch 34/100
# 258/258 [==============================] - 131s 509ms/step - loss: 0.9237 - accuracy: 0.9520 - iou_score: 0.2828 - val_loss: 0.9269 - val_accuracy: 0.9503 - val_iou_score: 0.2705
# Epoch 35/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.9235 - accuracy: 0.9520 - iou_score: 0.2836 - val_loss: 0.9271 - val_accuracy: 0.9503 - val_iou_score: 0.2703
# Epoch 36/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.9233 - accuracy: 0.9520 - iou_score: 0.2839 - val_loss: 0.9277 - val_accuracy: 0.9503 - val_iou_score: 0.2700
# Epoch 37/100
# 258/258 [==============================] - 131s 510ms/step - loss: 0.9225 - accuracy: 0.9507 - iou_score: 0.2865 - val_loss: 0.9273 - val_accuracy: 0.9420 - val_iou_score: 0.2719
# Epoch 38/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.9226 - accuracy: 0.9514 - iou_score: 0.2860 - val_loss: 0.9293 - val_accuracy: 0.9500 - val_iou_score: 0.2690
# Epoch 39/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.9218 - accuracy: 0.9516 - iou_score: 0.2883 - val_loss: 0.9308 - val_accuracy: 0.9503 - val_iou_score: 0.2682
# Epoch 40/100
# 258/258 [==============================] - 131s 510ms/step - loss: 0.9199 - accuracy: 0.9520 - iou_score: 0.2951 - val_loss: 0.9322 - val_accuracy: 0.9503 - val_iou_score: 0.2670
# Epoch 41/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.9190 - accuracy: 0.9519 - iou_score: 0.2987 - val_loss: 0.9288 - val_accuracy: 0.9503 - val_iou_score: 0.2705
# Epoch 42/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.9173 - accuracy: 0.9520 - iou_score: 0.3032 - val_loss: 0.9311 - val_accuracy: 0.9503 - val_iou_score: 0.2669
# Epoch 43/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.9172 - accuracy: 0.9518 - iou_score: 0.3043 - val_loss: 0.9321 - val_accuracy: 0.9458 - val_iou_score: 0.2681
# Epoch 44/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.9151 - accuracy: 0.9505 - iou_score: 0.3099 - val_loss: 0.9322 - val_accuracy: 0.9497 - val_iou_score: 0.2684
# Epoch 45/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.9143 - accuracy: 0.9506 - iou_score: 0.3137 - val_loss: 0.9307 - val_accuracy: 0.9471 - val_iou_score: 0.2698
# Epoch 46/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.9110 - accuracy: 0.9505 - iou_score: 0.3234 - val_loss: 0.9341 - val_accuracy: 0.9458 - val_iou_score: 0.2632
# Epoch 47/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.9083 - accuracy: 0.9496 - iou_score: 0.3300 - val_loss: 0.9334 - val_accuracy: 0.9459 - val_iou_score: 0.2648
# Epoch 48/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.9084 - accuracy: 0.9490 - iou_score: 0.3312 - val_loss: 0.9378 - val_accuracy: 0.9461 - val_iou_score: 0.2641
# Epoch 49/100
# 258/258 [==============================] - 132s 513ms/step - loss: 0.9022 - accuracy: 0.9490 - iou_score: 0.3481 - val_loss: 0.9372 - val_accuracy: 0.9410 - val_iou_score: 0.2714
# Epoch 50/100
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8974 - accuracy: 0.9498 - iou_score: 0.3613 - val_loss: 0.9432 - val_accuracy: 0.9497 - val_iou_score: 0.2638
# Epoch 51/100
# 258/258 [==============================] - 131s 508ms/step - loss: 0.9001 - accuracy: 0.9498 - iou_score: 0.3538 - val_loss: 0.9459 - val_accuracy: 0.9488 - val_iou_score: 0.2618
# Epoch 52/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8952 - accuracy: 0.9499 - iou_score: 0.3662 - val_loss: 0.9492 - val_accuracy: 0.9480 - val_iou_score: 0.2621
# Epoch 53/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8916 - accuracy: 0.9506 - iou_score: 0.3765 - val_loss: 0.9512 - val_accuracy: 0.9462 - val_iou_score: 0.2560
# Epoch 54/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8886 - accuracy: 0.9507 - iou_score: 0.3845 - val_loss: 0.9505 - val_accuracy: 0.9484 - val_iou_score: 0.2593
# Epoch 55/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8887 - accuracy: 0.9503 - iou_score: 0.3842 - val_loss: 0.9548 - val_accuracy: 0.9483 - val_iou_score: 0.2569
# Epoch 56/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8856 - accuracy: 0.9511 - iou_score: 0.3933 - val_loss: 0.9518 - val_accuracy: 0.9469 - val_iou_score: 0.2600
# Epoch 57/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8816 - accuracy: 0.9514 - iou_score: 0.4045 - val_loss: 0.9562 - val_accuracy: 0.9490 - val_iou_score: 0.2607
# Epoch 58/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8788 - accuracy: 0.9518 - iou_score: 0.4122 - val_loss: 0.9596 - val_accuracy: 0.9495 - val_iou_score: 0.2581
# Epoch 59/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8787 - accuracy: 0.9517 - iou_score: 0.4132 - val_loss: 0.9543 - val_accuracy: 0.9494 - val_iou_score: 0.2587
# Epoch 60/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8761 - accuracy: 0.9520 - iou_score: 0.4203 - val_loss: 0.9578 - val_accuracy: 0.9494 - val_iou_score: 0.2640
# Epoch 61/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8764 - accuracy: 0.9522 - iou_score: 0.4190 - val_loss: 0.9591 - val_accuracy: 0.9499 - val_iou_score: 0.2537
# Epoch 62/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8753 - accuracy: 0.9522 - iou_score: 0.4232 - val_loss: 0.9625 - val_accuracy: 0.9501 - val_iou_score: 0.2591
# Epoch 63/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8728 - accuracy: 0.9521 - iou_score: 0.4298 - val_loss: 0.9613 - val_accuracy: 0.9503 - val_iou_score: 0.2522
# Epoch 64/100
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8738 - accuracy: 0.9521 - iou_score: 0.4270 - val_loss: 0.9609 - val_accuracy: 0.9502 - val_iou_score: 0.2629
# Epoch 65/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8770 - accuracy: 0.9521 - iou_score: 0.4192 - val_loss: 0.9580 - val_accuracy: 0.9503 - val_iou_score: 0.2565
# Epoch 66/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8763 - accuracy: 0.9520 - iou_score: 0.4201 - val_loss: 0.9631 - val_accuracy: 0.9503 - val_iou_score: 0.2533
# Epoch 67/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8706 - accuracy: 0.9522 - iou_score: 0.4371 - val_loss: 0.9615 - val_accuracy: 0.9502 - val_iou_score: 0.2598
# Epoch 68/100
# 258/258 [==============================] - 131s 510ms/step - loss: 0.8693 - accuracy: 0.9522 - iou_score: 0.4408 - val_loss: 0.9624 - val_accuracy: 0.9503 - val_iou_score: 0.2538
# Epoch 69/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8650 - accuracy: 0.9520 - iou_score: 0.4555 - val_loss: 0.9644 - val_accuracy: 0.9503 - val_iou_score: 0.2562
# Epoch 70/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8626 - accuracy: 0.9520 - iou_score: 0.4644 - val_loss: 0.9655 - val_accuracy: 0.9503 - val_iou_score: 0.2512
# Epoch 71/100
# 258/258 [==============================] - 131s 509ms/step - loss: 0.8615 - accuracy: 0.9520 - iou_score: 0.4674 - val_loss: 0.9652 - val_accuracy: 0.9503 - val_iou_score: 0.2566
# Epoch 72/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8621 - accuracy: 0.9520 - iou_score: 0.4652 - val_loss: 0.9655 - val_accuracy: 0.9503 - val_iou_score: 0.2526
# Epoch 73/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8604 - accuracy: 0.9520 - iou_score: 0.4709 - val_loss: 0.9650 - val_accuracy: 0.9503 - val_iou_score: 0.2597
# Epoch 74/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8579 - accuracy: 0.9520 - iou_score: 0.4789 - val_loss: 0.9623 - val_accuracy: 0.9503 - val_iou_score: 0.2578
# Epoch 75/100
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8591 - accuracy: 0.9520 - iou_score: 0.4746 - val_loss: 0.9638 - val_accuracy: 0.9503 - val_iou_score: 0.2521
# Epoch 76/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8625 - accuracy: 0.9520 - iou_score: 0.4643 - val_loss: 0.9667 - val_accuracy: 0.9503 - val_iou_score: 0.2610
# Epoch 77/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8577 - accuracy: 0.9520 - iou_score: 0.4792 - val_loss: 0.9653 - val_accuracy: 0.9503 - val_iou_score: 0.2593
# Epoch 78/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8552 - accuracy: 0.9520 - iou_score: 0.4875 - val_loss: 0.9672 - val_accuracy: 0.9503 - val_iou_score: 0.2601
# Epoch 79/100
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8522 - accuracy: 0.9520 - iou_score: 0.4977 - val_loss: 0.9664 - val_accuracy: 0.9503 - val_iou_score: 0.2611
# Epoch 80/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8515 - accuracy: 0.9520 - iou_score: 0.5007 - val_loss: 0.9714 - val_accuracy: 0.9503 - val_iou_score: 0.2602
# Epoch 81/100
# 258/258 [==============================] - 133s 514ms/step - loss: 0.8530 - accuracy: 0.9520 - iou_score: 0.4956 - val_loss: 0.9702 - val_accuracy: 0.9503 - val_iou_score: 0.2576
# Epoch 82/100
# 258/258 [==============================] - 133s 515ms/step - loss: 0.8524 - accuracy: 0.9520 - iou_score: 0.4967 - val_loss: 0.9664 - val_accuracy: 0.9503 - val_iou_score: 0.2625
# Epoch 83/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8519 - accuracy: 0.9520 - iou_score: 0.4989 - val_loss: 0.9666 - val_accuracy: 0.9503 - val_iou_score: 0.2583
# Epoch 84/100
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8493 - accuracy: 0.9520 - iou_score: 0.5079 - val_loss: 0.9721 - val_accuracy: 0.9503 - val_iou_score: 0.2604
# Epoch 85/100
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8491 - accuracy: 0.9520 - iou_score: 0.5080 - val_loss: 0.9724 - val_accuracy: 0.9503 - val_iou_score: 0.2613
# Epoch 86/100
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8509 - accuracy: 0.9520 - iou_score: 0.5031 - val_loss: 0.9695 - val_accuracy: 0.9503 - val_iou_score: 0.2628
# Epoch 87/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8499 - accuracy: 0.9520 - iou_score: 0.5061 - val_loss: 0.9686 - val_accuracy: 0.9503 - val_iou_score: 0.2590
# Epoch 88/100
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8481 - accuracy: 0.9520 - iou_score: 0.5122 - val_loss: 0.9715 - val_accuracy: 0.9503 - val_iou_score: 0.2619
# Epoch 89/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8463 - accuracy: 0.9520 - iou_score: 0.5185 - val_loss: 0.9677 - val_accuracy: 0.9503 - val_iou_score: 0.2627
# Epoch 90/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8465 - accuracy: 0.9520 - iou_score: 0.5183 - val_loss: 0.9711 - val_accuracy: 0.9503 - val_iou_score: 0.2579
# Epoch 91/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8459 - accuracy: 0.9520 - iou_score: 0.5207 - val_loss: 0.9714 - val_accuracy: 0.9503 - val_iou_score: 0.2543
# Epoch 92/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8443 - accuracy: 0.9520 - iou_score: 0.5265 - val_loss: 0.9713 - val_accuracy: 0.9503 - val_iou_score: 0.2578
# Epoch 93/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8430 - accuracy: 0.9520 - iou_score: 0.5314 - val_loss: 0.9737 - val_accuracy: 0.9503 - val_iou_score: 0.2572
# Epoch 94/100
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8426 - accuracy: 0.9520 - iou_score: 0.5329 - val_loss: 0.9737 - val_accuracy: 0.9503 - val_iou_score: 0.2577
# Epoch 95/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8428 - accuracy: 0.9520 - iou_score: 0.5322 - val_loss: 0.9738 - val_accuracy: 0.9503 - val_iou_score: 0.2573
# Epoch 96/100
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8423 - accuracy: 0.9520 - iou_score: 0.5338 - val_loss: 0.9687 - val_accuracy: 0.9503 - val_iou_score: 0.2572
# Epoch 97/100
# 258/258 [==============================] - 132s 510ms/step - loss: 0.8419 - accuracy: 0.9520 - iou_score: 0.5356 - val_loss: 0.9699 - val_accuracy: 0.9503 - val_iou_score: 0.2570
# Epoch 98/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8411 - accuracy: 0.9520 - iou_score: 0.5381 - val_loss: 0.9744 - val_accuracy: 0.9503 - val_iou_score: 0.2557
# Epoch 99/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8419 - accuracy: 0.9520 - iou_score: 0.5353 - val_loss: 0.9761 - val_accuracy: 0.9503 - val_iou_score: 0.2526
# Epoch 100/100
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8410 - accuracy: 0.9520 - iou_score: 0.5391 - val_loss: 0.9749 - val_accuracy: 0.9503 - val_iou_score: 0.2537

# %%
history=model5.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=500,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )
# Out:
# Epoch 1/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8408 - accuracy: 0.9520 - iou_score: 0.5404 - val_loss: 0.9741 - val_accuracy: 0.9503 - val_iou_score: 0.2560
# Epoch 2/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8402 - accuracy: 0.9520 - iou_score: 0.5419 - val_loss: 0.9724 - val_accuracy: 0.9503 - val_iou_score: 0.2559
# Epoch 3/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8389 - accuracy: 0.9520 - iou_score: 0.5469 - val_loss: 0.9738 - val_accuracy: 0.9503 - val_iou_score: 0.2562
# Epoch 4/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8373 - accuracy: 0.9520 - iou_score: 0.5532 - val_loss: 0.9734 - val_accuracy: 0.9503 - val_iou_score: 0.2537
# Epoch 5/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8368 - accuracy: 0.9520 - iou_score: 0.5550 - val_loss: 0.9767 - val_accuracy: 0.9503 - val_iou_score: 0.2509
# Epoch 6/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8372 - accuracy: 0.9520 - iou_score: 0.5534 - val_loss: 0.9753 - val_accuracy: 0.9503 - val_iou_score: 0.2540
# Epoch 7/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8365 - accuracy: 0.9520 - iou_score: 0.5560 - val_loss: 0.9757 - val_accuracy: 0.9503 - val_iou_score: 0.2534
# Epoch 8/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8357 - accuracy: 0.9520 - iou_score: 0.5588 - val_loss: 0.9756 - val_accuracy: 0.9503 - val_iou_score: 0.2569
# Epoch 9/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.8358 - accuracy: 0.9521 - iou_score: 0.5586 - val_loss: 0.9741 - val_accuracy: 0.9503 - val_iou_score: 0.2564
# Epoch 10/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8348 - accuracy: 0.9521 - iou_score: 0.5619 - val_loss: 0.9772 - val_accuracy: 0.9503 - val_iou_score: 0.2500
# Epoch 11/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8345 - accuracy: 0.9521 - iou_score: 0.5636 - val_loss: 0.9753 - val_accuracy: 0.9503 - val_iou_score: 0.2568
# Epoch 12/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.8347 - accuracy: 0.9522 - iou_score: 0.5628 - val_loss: 0.9711 - val_accuracy: 0.9502 - val_iou_score: 0.2537
# Epoch 13/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.8342 - accuracy: 0.9521 - iou_score: 0.5651 - val_loss: 0.9726 - val_accuracy: 0.9503 - val_iou_score: 0.2516
# Epoch 14/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8326 - accuracy: 0.9521 - iou_score: 0.5715 - val_loss: 0.9739 - val_accuracy: 0.9503 - val_iou_score: 0.2531
# Epoch 15/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8321 - accuracy: 0.9521 - iou_score: 0.5732 - val_loss: 0.9758 - val_accuracy: 0.9503 - val_iou_score: 0.2497
# Epoch 16/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8322 - accuracy: 0.9522 - iou_score: 0.5726 - val_loss: 0.9749 - val_accuracy: 0.9503 - val_iou_score: 0.2510
# Epoch 17/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8317 - accuracy: 0.9523 - iou_score: 0.5747 - val_loss: 0.9769 - val_accuracy: 0.9503 - val_iou_score: 0.2532
# Epoch 18/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.8323 - accuracy: 0.9521 - iou_score: 0.5727 - val_loss: 0.9756 - val_accuracy: 0.9503 - val_iou_score: 0.2483
# Epoch 19/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.8324 - accuracy: 0.9522 - iou_score: 0.5721 - val_loss: 0.9735 - val_accuracy: 0.9503 - val_iou_score: 0.2480
# Epoch 20/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.8314 - accuracy: 0.9525 - iou_score: 0.5758 - val_loss: 0.9745 - val_accuracy: 0.9502 - val_iou_score: 0.2528
# Epoch 21/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8336 - accuracy: 0.9524 - iou_score: 0.5678 - val_loss: 0.9743 - val_accuracy: 0.9503 - val_iou_score: 0.2540
# Epoch 22/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8297 - accuracy: 0.9532 - iou_score: 0.5831 - val_loss: 0.9769 - val_accuracy: 0.9497 - val_iou_score: 0.2500
# Epoch 23/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.8280 - accuracy: 0.9635 - iou_score: 0.5914 - val_loss: 0.9754 - val_accuracy: 0.9442 - val_iou_score: 0.2526
# Epoch 24/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8276 - accuracy: 0.9761 - iou_score: 0.5948 - val_loss: 0.9767 - val_accuracy: 0.9455 - val_iou_score: 0.2521
# Epoch 25/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.8280 - accuracy: 0.9757 - iou_score: 0.5932 - val_loss: 0.9763 - val_accuracy: 0.9459 - val_iou_score: 0.2499
# Epoch 26/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.8280 - accuracy: 0.9757 - iou_score: 0.5931 - val_loss: 0.9774 - val_accuracy: 0.9443 - val_iou_score: 0.2502
# Epoch 27/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.8271 - accuracy: 0.9761 - iou_score: 0.5973 - val_loss: 0.9767 - val_accuracy: 0.9448 - val_iou_score: 0.2501
# Epoch 28/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.8275 - accuracy: 0.9758 - iou_score: 0.5952 - val_loss: 0.9772 - val_accuracy: 0.9469 - val_iou_score: 0.2550
# Epoch 29/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8270 - accuracy: 0.9764 - iou_score: 0.5973 - val_loss: 0.9790 - val_accuracy: 0.9455 - val_iou_score: 0.2521
# Epoch 30/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8260 - accuracy: 0.9765 - iou_score: 0.6015 - val_loss: 0.9806 - val_accuracy: 0.9467 - val_iou_score: 0.2491
# Epoch 31/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.8260 - accuracy: 0.9764 - iou_score: 0.6020 - val_loss: 0.9780 - val_accuracy: 0.9436 - val_iou_score: 0.2523
# Epoch 32/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.8263 - accuracy: 0.9767 - iou_score: 0.6002 - val_loss: 0.9774 - val_accuracy: 0.9444 - val_iou_score: 0.2493
# Epoch 33/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8262 - accuracy: 0.9766 - iou_score: 0.6006 - val_loss: 0.9774 - val_accuracy: 0.9470 - val_iou_score: 0.2492
# Epoch 34/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8255 - accuracy: 0.9771 - iou_score: 0.6037 - val_loss: 0.9788 - val_accuracy: 0.9463 - val_iou_score: 0.2492
# Epoch 35/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8251 - accuracy: 0.9772 - iou_score: 0.6051 - val_loss: 0.9756 - val_accuracy: 0.9435 - val_iou_score: 0.2532
# Epoch 36/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8270 - accuracy: 0.9761 - iou_score: 0.5977 - val_loss: 0.9753 - val_accuracy: 0.9455 - val_iou_score: 0.2524
# Epoch 37/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.8240 - accuracy: 0.9781 - iou_score: 0.6103 - val_loss: 0.9782 - val_accuracy: 0.9459 - val_iou_score: 0.2520
# Epoch 38/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8228 - accuracy: 0.9786 - iou_score: 0.6151 - val_loss: 0.9802 - val_accuracy: 0.9476 - val_iou_score: 0.2491
# Epoch 39/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8231 - accuracy: 0.9788 - iou_score: 0.6141 - val_loss: 0.9801 - val_accuracy: 0.9465 - val_iou_score: 0.2496
# Epoch 40/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8237 - accuracy: 0.9790 - iou_score: 0.6123 - val_loss: 0.9767 - val_accuracy: 0.9416 - val_iou_score: 0.2490
# Epoch 41/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.8236 - accuracy: 0.9790 - iou_score: 0.6120 - val_loss: 0.9773 - val_accuracy: 0.9458 - val_iou_score: 0.2549
# Epoch 42/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8233 - accuracy: 0.9786 - iou_score: 0.6134 - val_loss: 0.9761 - val_accuracy: 0.9442 - val_iou_score: 0.2516
# Epoch 43/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8220 - accuracy: 0.9794 - iou_score: 0.6193 - val_loss: 0.9758 - val_accuracy: 0.9460 - val_iou_score: 0.2523
# Epoch 44/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8218 - accuracy: 0.9794 - iou_score: 0.6203 - val_loss: 0.9787 - val_accuracy: 0.9462 - val_iou_score: 0.2523
# Epoch 45/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.8219 - accuracy: 0.9795 - iou_score: 0.6198 - val_loss: 0.9760 - val_accuracy: 0.9449 - val_iou_score: 0.2503
# Epoch 46/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8222 - accuracy: 0.9796 - iou_score: 0.6182 - val_loss: 0.9764 - val_accuracy: 0.9469 - val_iou_score: 0.2523
# Epoch 47/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8219 - accuracy: 0.9793 - iou_score: 0.6193 - val_loss: 0.9790 - val_accuracy: 0.9479 - val_iou_score: 0.2525
# Epoch 48/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8202 - accuracy: 0.9805 - iou_score: 0.6266 - val_loss: 0.9798 - val_accuracy: 0.9472 - val_iou_score: 0.2492
# Epoch 49/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.8191 - accuracy: 0.9808 - iou_score: 0.6324 - val_loss: 0.9791 - val_accuracy: 0.9451 - val_iou_score: 0.2498
# Epoch 50/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.8193 - accuracy: 0.9808 - iou_score: 0.6309 - val_loss: 0.9796 - val_accuracy: 0.9447 - val_iou_score: 0.2528
# Epoch 51/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8219 - accuracy: 0.9796 - iou_score: 0.6205 - val_loss: 0.9715 - val_accuracy: 0.9382 - val_iou_score: 0.2481
# Epoch 52/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8211 - accuracy: 0.9797 - iou_score: 0.6233 - val_loss: 0.9770 - val_accuracy: 0.9466 - val_iou_score: 0.2520
# Epoch 53/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8192 - accuracy: 0.9809 - iou_score: 0.6312 - val_loss: 0.9780 - val_accuracy: 0.9467 - val_iou_score: 0.2525
# Epoch 54/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.8182 - accuracy: 0.9812 - iou_score: 0.6360 - val_loss: 0.9792 - val_accuracy: 0.9460 - val_iou_score: 0.2549
# Epoch 55/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8176 - accuracy: 0.9814 - iou_score: 0.6385 - val_loss: 0.9787 - val_accuracy: 0.9455 - val_iou_score: 0.2522
# Epoch 56/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8176 - accuracy: 0.9815 - iou_score: 0.6385 - val_loss: 0.9783 - val_accuracy: 0.9460 - val_iou_score: 0.2555
# Epoch 57/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8178 - accuracy: 0.9815 - iou_score: 0.6378 - val_loss: 0.9785 - val_accuracy: 0.9476 - val_iou_score: 0.2548
# Epoch 58/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.8174 - accuracy: 0.9817 - iou_score: 0.6384 - val_loss: 0.9798 - val_accuracy: 0.9484 - val_iou_score: 0.2547
# Epoch 59/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8175 - accuracy: 0.9816 - iou_score: 0.6389 - val_loss: 0.9787 - val_accuracy: 0.9470 - val_iou_score: 0.2547
# Epoch 60/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8164 - accuracy: 0.9822 - iou_score: 0.6439 - val_loss: 0.9776 - val_accuracy: 0.9476 - val_iou_score: 0.2551
# Epoch 61/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.8166 - accuracy: 0.9820 - iou_score: 0.6431 - val_loss: 0.9764 - val_accuracy: 0.9451 - val_iou_score: 0.2551
# Epoch 62/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.8173 - accuracy: 0.9815 - iou_score: 0.6390 - val_loss: 0.9787 - val_accuracy: 0.9468 - val_iou_score: 0.2548
# Epoch 63/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.8166 - accuracy: 0.9817 - iou_score: 0.6424 - val_loss: 0.9801 - val_accuracy: 0.9482 - val_iou_score: 0.2547
# Epoch 64/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8157 - accuracy: 0.9825 - iou_score: 0.6466 - val_loss: 0.9799 - val_accuracy: 0.9456 - val_iou_score: 0.2549
# Epoch 65/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8155 - accuracy: 0.9828 - iou_score: 0.6477 - val_loss: 0.9777 - val_accuracy: 0.9462 - val_iou_score: 0.2499
# Epoch 66/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8155 - accuracy: 0.9831 - iou_score: 0.6479 - val_loss: 0.9794 - val_accuracy: 0.9468 - val_iou_score: 0.2547
# Epoch 67/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8156 - accuracy: 0.9828 - iou_score: 0.6471 - val_loss: 0.9804 - val_accuracy: 0.9477 - val_iou_score: 0.2550
# Epoch 68/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8148 - accuracy: 0.9829 - iou_score: 0.6509 - val_loss: 0.9786 - val_accuracy: 0.9469 - val_iou_score: 0.2522
# Epoch 69/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8153 - accuracy: 0.9824 - iou_score: 0.6488 - val_loss: 0.9774 - val_accuracy: 0.9453 - val_iou_score: 0.2548
# Epoch 70/500
# 258/258 [==============================] - 131s 509ms/step - loss: 0.8151 - accuracy: 0.9828 - iou_score: 0.6497 - val_loss: 0.9807 - val_accuracy: 0.9476 - val_iou_score: 0.2520
# Epoch 71/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8139 - accuracy: 0.9833 - iou_score: 0.6549 - val_loss: 0.9795 - val_accuracy: 0.9467 - val_iou_score: 0.2517
# Epoch 72/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.8149 - accuracy: 0.9830 - iou_score: 0.6499 - val_loss: 0.9823 - val_accuracy: 0.9484 - val_iou_score: 0.2519
# Epoch 73/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8148 - accuracy: 0.9828 - iou_score: 0.6508 - val_loss: 0.9784 - val_accuracy: 0.9468 - val_iou_score: 0.2523
# Epoch 74/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.8141 - accuracy: 0.9830 - iou_score: 0.6535 - val_loss: 0.9788 - val_accuracy: 0.9449 - val_iou_score: 0.2497
# Epoch 75/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8133 - accuracy: 0.9832 - iou_score: 0.6568 - val_loss: 0.9792 - val_accuracy: 0.9468 - val_iou_score: 0.2518
# Epoch 76/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8136 - accuracy: 0.9831 - iou_score: 0.6559 - val_loss: 0.9818 - val_accuracy: 0.9483 - val_iou_score: 0.2550
# Epoch 77/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.8130 - accuracy: 0.9837 - iou_score: 0.6587 - val_loss: 0.9805 - val_accuracy: 0.9466 - val_iou_score: 0.2552
# Epoch 78/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8131 - accuracy: 0.9834 - iou_score: 0.6583 - val_loss: 0.9807 - val_accuracy: 0.9446 - val_iou_score: 0.2525
# Epoch 79/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.8128 - accuracy: 0.9834 - iou_score: 0.6596 - val_loss: 0.9788 - val_accuracy: 0.9473 - val_iou_score: 0.2547
# Epoch 80/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8122 - accuracy: 0.9840 - iou_score: 0.6621 - val_loss: 0.9782 - val_accuracy: 0.9462 - val_iou_score: 0.2546
# Epoch 81/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8121 - accuracy: 0.9840 - iou_score: 0.6631 - val_loss: 0.9772 - val_accuracy: 0.9453 - val_iou_score: 0.2492
# Epoch 82/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8120 - accuracy: 0.9840 - iou_score: 0.6649 - val_loss: 0.9808 - val_accuracy: 0.9463 - val_iou_score: 0.2441
# Epoch 83/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8117 - accuracy: 0.9840 - iou_score: 0.6643 - val_loss: 0.9797 - val_accuracy: 0.9457 - val_iou_score: 0.2492
# Epoch 84/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8113 - accuracy: 0.9842 - iou_score: 0.6663 - val_loss: 0.9799 - val_accuracy: 0.9476 - val_iou_score: 0.2575
# Epoch 85/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8119 - accuracy: 0.9838 - iou_score: 0.6633 - val_loss: 0.9794 - val_accuracy: 0.9443 - val_iou_score: 0.2468
# Epoch 86/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8117 - accuracy: 0.9839 - iou_score: 0.6644 - val_loss: 0.9821 - val_accuracy: 0.9472 - val_iou_score: 0.2492
# Epoch 87/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8109 - accuracy: 0.9842 - iou_score: 0.6680 - val_loss: 0.9805 - val_accuracy: 0.9482 - val_iou_score: 0.2577
# Epoch 88/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8103 - accuracy: 0.9846 - iou_score: 0.6706 - val_loss: 0.9802 - val_accuracy: 0.9477 - val_iou_score: 0.2551
# Epoch 89/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8116 - accuracy: 0.9841 - iou_score: 0.6661 - val_loss: 0.9792 - val_accuracy: 0.9472 - val_iou_score: 0.2523
# Epoch 90/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8109 - accuracy: 0.9844 - iou_score: 0.6681 - val_loss: 0.9801 - val_accuracy: 0.9463 - val_iou_score: 0.2495
# Epoch 91/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8115 - accuracy: 0.9839 - iou_score: 0.6653 - val_loss: 0.9809 - val_accuracy: 0.9467 - val_iou_score: 0.2518
# Epoch 92/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8100 - accuracy: 0.9846 - iou_score: 0.6721 - val_loss: 0.9781 - val_accuracy: 0.9448 - val_iou_score: 0.2490
# Epoch 93/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8100 - accuracy: 0.9845 - iou_score: 0.6718 - val_loss: 0.9805 - val_accuracy: 0.9464 - val_iou_score: 0.2579
# Epoch 94/500
# 258/258 [==============================] - 131s 509ms/step - loss: 0.8106 - accuracy: 0.9847 - iou_score: 0.6703 - val_loss: 0.9774 - val_accuracy: 0.9436 - val_iou_score: 0.2557
# Epoch 95/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8101 - accuracy: 0.9846 - iou_score: 0.6716 - val_loss: 0.9814 - val_accuracy: 0.9486 - val_iou_score: 0.2548
# Epoch 96/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8101 - accuracy: 0.9844 - iou_score: 0.6719 - val_loss: 0.9799 - val_accuracy: 0.9474 - val_iou_score: 0.2550
# Epoch 97/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8095 - accuracy: 0.9847 - iou_score: 0.6750 - val_loss: 0.9813 - val_accuracy: 0.9459 - val_iou_score: 0.2519
# Epoch 98/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8096 - accuracy: 0.9847 - iou_score: 0.6737 - val_loss: 0.9825 - val_accuracy: 0.9487 - val_iou_score: 0.2578
# Epoch 99/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8093 - accuracy: 0.9849 - iou_score: 0.6761 - val_loss: 0.9817 - val_accuracy: 0.9465 - val_iou_score: 0.2548
# Epoch 100/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8098 - accuracy: 0.9847 - iou_score: 0.6735 - val_loss: 0.9792 - val_accuracy: 0.9472 - val_iou_score: 0.2549
# Epoch 101/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8093 - accuracy: 0.9849 - iou_score: 0.6745 - val_loss: 0.9818 - val_accuracy: 0.9452 - val_iou_score: 0.2530
# Epoch 102/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8094 - accuracy: 0.9848 - iou_score: 0.6747 - val_loss: 0.9807 - val_accuracy: 0.9487 - val_iou_score: 0.2552
# Epoch 103/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8081 - accuracy: 0.9851 - iou_score: 0.6799 - val_loss: 0.9798 - val_accuracy: 0.9449 - val_iou_score: 0.2524
# Epoch 104/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8088 - accuracy: 0.9850 - iou_score: 0.6781 - val_loss: 0.9786 - val_accuracy: 0.9445 - val_iou_score: 0.2537
# Epoch 105/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8091 - accuracy: 0.9850 - iou_score: 0.6768 - val_loss: 0.9796 - val_accuracy: 0.9468 - val_iou_score: 0.2553
# Epoch 106/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.8085 - accuracy: 0.9851 - iou_score: 0.6782 - val_loss: 0.9818 - val_accuracy: 0.9486 - val_iou_score: 0.2550
# Epoch 107/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8085 - accuracy: 0.9852 - iou_score: 0.6782 - val_loss: 0.9790 - val_accuracy: 0.9481 - val_iou_score: 0.2527
# Epoch 108/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8091 - accuracy: 0.9849 - iou_score: 0.6755 - val_loss: 0.9814 - val_accuracy: 0.9464 - val_iou_score: 0.2520
# Epoch 109/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8087 - accuracy: 0.9849 - iou_score: 0.6776 - val_loss: 0.9807 - val_accuracy: 0.9463 - val_iou_score: 0.2493
# Epoch 110/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8081 - accuracy: 0.9851 - iou_score: 0.6802 - val_loss: 0.9796 - val_accuracy: 0.9466 - val_iou_score: 0.2523
# Epoch 111/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8083 - accuracy: 0.9851 - iou_score: 0.6816 - val_loss: 0.9782 - val_accuracy: 0.9457 - val_iou_score: 0.2519
# Epoch 112/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8089 - accuracy: 0.9851 - iou_score: 0.6773 - val_loss: 0.9801 - val_accuracy: 0.9470 - val_iou_score: 0.2577
# Epoch 113/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8070 - accuracy: 0.9856 - iou_score: 0.6859 - val_loss: 0.9812 - val_accuracy: 0.9481 - val_iou_score: 0.2519
# Epoch 114/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8062 - accuracy: 0.9858 - iou_score: 0.6894 - val_loss: 0.9810 - val_accuracy: 0.9481 - val_iou_score: 0.2549
# Epoch 115/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8060 - accuracy: 0.9859 - iou_score: 0.6899 - val_loss: 0.9798 - val_accuracy: 0.9448 - val_iou_score: 0.2523
# Epoch 116/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8063 - accuracy: 0.9858 - iou_score: 0.6885 - val_loss: 0.9805 - val_accuracy: 0.9465 - val_iou_score: 0.2519
# Epoch 117/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8071 - accuracy: 0.9856 - iou_score: 0.6850 - val_loss: 0.9813 - val_accuracy: 0.9457 - val_iou_score: 0.2494
# Epoch 118/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8064 - accuracy: 0.9858 - iou_score: 0.6880 - val_loss: 0.9791 - val_accuracy: 0.9465 - val_iou_score: 0.2521
# Epoch 119/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8057 - accuracy: 0.9860 - iou_score: 0.6914 - val_loss: 0.9800 - val_accuracy: 0.9458 - val_iou_score: 0.2548
# Epoch 120/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8062 - accuracy: 0.9859 - iou_score: 0.6884 - val_loss: 0.9797 - val_accuracy: 0.9461 - val_iou_score: 0.2554
# Epoch 121/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8072 - accuracy: 0.9856 - iou_score: 0.6841 - val_loss: 0.9794 - val_accuracy: 0.9439 - val_iou_score: 0.2527
# Epoch 122/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8061 - accuracy: 0.9859 - iou_score: 0.6897 - val_loss: 0.9811 - val_accuracy: 0.9474 - val_iou_score: 0.2520
# Epoch 123/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8059 - accuracy: 0.9860 - iou_score: 0.6898 - val_loss: 0.9825 - val_accuracy: 0.9475 - val_iou_score: 0.2577
# Epoch 124/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8062 - accuracy: 0.9860 - iou_score: 0.6898 - val_loss: 0.9834 - val_accuracy: 0.9491 - val_iou_score: 0.2578
# Epoch 125/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8061 - accuracy: 0.9859 - iou_score: 0.6898 - val_loss: 0.9830 - val_accuracy: 0.9479 - val_iou_score: 0.2550
# Epoch 126/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8059 - accuracy: 0.9858 - iou_score: 0.6899 - val_loss: 0.9812 - val_accuracy: 0.9460 - val_iou_score: 0.2551
# Epoch 127/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8066 - accuracy: 0.9855 - iou_score: 0.6866 - val_loss: 0.9811 - val_accuracy: 0.9446 - val_iou_score: 0.2528
# Epoch 128/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8066 - accuracy: 0.9855 - iou_score: 0.6866 - val_loss: 0.9791 - val_accuracy: 0.9439 - val_iou_score: 0.2491
# Epoch 129/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8057 - accuracy: 0.9860 - iou_score: 0.6914 - val_loss: 0.9792 - val_accuracy: 0.9460 - val_iou_score: 0.2550
# Epoch 130/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8049 - accuracy: 0.9862 - iou_score: 0.6948 - val_loss: 0.9808 - val_accuracy: 0.9459 - val_iou_score: 0.2550
# Epoch 131/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8048 - accuracy: 0.9863 - iou_score: 0.6959 - val_loss: 0.9832 - val_accuracy: 0.9485 - val_iou_score: 0.2549
# Epoch 132/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8049 - accuracy: 0.9862 - iou_score: 0.6952 - val_loss: 0.9825 - val_accuracy: 0.9485 - val_iou_score: 0.2552
# Epoch 133/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8058 - accuracy: 0.9860 - iou_score: 0.6904 - val_loss: 0.9823 - val_accuracy: 0.9481 - val_iou_score: 0.2550
# Epoch 134/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8056 - accuracy: 0.9861 - iou_score: 0.6913 - val_loss: 0.9809 - val_accuracy: 0.9455 - val_iou_score: 0.2469
# Epoch 135/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8048 - accuracy: 0.9863 - iou_score: 0.6955 - val_loss: 0.9800 - val_accuracy: 0.9457 - val_iou_score: 0.2493
# Epoch 136/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8044 - accuracy: 0.9865 - iou_score: 0.6978 - val_loss: 0.9782 - val_accuracy: 0.9445 - val_iou_score: 0.2494
# Epoch 137/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8037 - accuracy: 0.9867 - iou_score: 0.6995 - val_loss: 0.9801 - val_accuracy: 0.9448 - val_iou_score: 0.2495
# Epoch 138/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8045 - accuracy: 0.9865 - iou_score: 0.6964 - val_loss: 0.9808 - val_accuracy: 0.9476 - val_iou_score: 0.2552
# Epoch 139/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8045 - accuracy: 0.9864 - iou_score: 0.6965 - val_loss: 0.9795 - val_accuracy: 0.9480 - val_iou_score: 0.2580
# Epoch 140/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8053 - accuracy: 0.9863 - iou_score: 0.6931 - val_loss: 0.9807 - val_accuracy: 0.9475 - val_iou_score: 0.2551
# Epoch 141/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8044 - accuracy: 0.9865 - iou_score: 0.6975 - val_loss: 0.9807 - val_accuracy: 0.9467 - val_iou_score: 0.2523
# Epoch 142/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8044 - accuracy: 0.9866 - iou_score: 0.6980 - val_loss: 0.9812 - val_accuracy: 0.9476 - val_iou_score: 0.2549
# Epoch 143/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8033 - accuracy: 0.9867 - iou_score: 0.7036 - val_loss: 0.9815 - val_accuracy: 0.9477 - val_iou_score: 0.2523
# Epoch 144/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8042 - accuracy: 0.9866 - iou_score: 0.6975 - val_loss: 0.9792 - val_accuracy: 0.9439 - val_iou_score: 0.2499
# Epoch 145/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8038 - accuracy: 0.9867 - iou_score: 0.7004 - val_loss: 0.9794 - val_accuracy: 0.9456 - val_iou_score: 0.2526
# Epoch 146/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8034 - accuracy: 0.9868 - iou_score: 0.7023 - val_loss: 0.9829 - val_accuracy: 0.9466 - val_iou_score: 0.2551
# Epoch 147/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8035 - accuracy: 0.9868 - iou_score: 0.7018 - val_loss: 0.9807 - val_accuracy: 0.9476 - val_iou_score: 0.2493
# Epoch 148/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8031 - accuracy: 0.9869 - iou_score: 0.7025 - val_loss: 0.9823 - val_accuracy: 0.9489 - val_iou_score: 0.2549
# Epoch 149/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8030 - accuracy: 0.9869 - iou_score: 0.7031 - val_loss: 0.9803 - val_accuracy: 0.9489 - val_iou_score: 0.2554
# Epoch 150/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8040 - accuracy: 0.9867 - iou_score: 0.7003 - val_loss: 0.9812 - val_accuracy: 0.9460 - val_iou_score: 0.2522
# Epoch 151/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8036 - accuracy: 0.9868 - iou_score: 0.7010 - val_loss: 0.9799 - val_accuracy: 0.9446 - val_iou_score: 0.2521
# Epoch 152/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8031 - accuracy: 0.9867 - iou_score: 0.7028 - val_loss: 0.9794 - val_accuracy: 0.9440 - val_iou_score: 0.2468
# Epoch 153/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8046 - accuracy: 0.9866 - iou_score: 0.6982 - val_loss: 0.9840 - val_accuracy: 0.9453 - val_iou_score: 0.2471
# Epoch 154/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8041 - accuracy: 0.9865 - iou_score: 0.6982 - val_loss: 0.9823 - val_accuracy: 0.9477 - val_iou_score: 0.2524
# Epoch 155/500
# 258/258 [==============================] - 131s 510ms/step - loss: 0.8026 - accuracy: 0.9870 - iou_score: 0.7049 - val_loss: 0.9820 - val_accuracy: 0.9485 - val_iou_score: 0.2552
# Epoch 156/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8021 - accuracy: 0.9872 - iou_score: 0.7084 - val_loss: 0.9814 - val_accuracy: 0.9477 - val_iou_score: 0.2551
# Epoch 157/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8022 - accuracy: 0.9872 - iou_score: 0.7082 - val_loss: 0.9808 - val_accuracy: 0.9470 - val_iou_score: 0.2521
# Epoch 158/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8020 - accuracy: 0.9872 - iou_score: 0.7080 - val_loss: 0.9784 - val_accuracy: 0.9438 - val_iou_score: 0.2465
# Epoch 159/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8018 - accuracy: 0.9873 - iou_score: 0.7083 - val_loss: 0.9796 - val_accuracy: 0.9457 - val_iou_score: 0.2467
# Epoch 160/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8025 - accuracy: 0.9871 - iou_score: 0.7071 - val_loss: 0.9786 - val_accuracy: 0.9437 - val_iou_score: 0.2495
# Epoch 161/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8026 - accuracy: 0.9870 - iou_score: 0.7060 - val_loss: 0.9801 - val_accuracy: 0.9431 - val_iou_score: 0.2439
# Epoch 162/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8027 - accuracy: 0.9869 - iou_score: 0.7043 - val_loss: 0.9815 - val_accuracy: 0.9477 - val_iou_score: 0.2465
# Epoch 163/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8018 - accuracy: 0.9871 - iou_score: 0.7093 - val_loss: 0.9819 - val_accuracy: 0.9490 - val_iou_score: 0.2582
# Epoch 164/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8017 - accuracy: 0.9873 - iou_score: 0.7092 - val_loss: 0.9826 - val_accuracy: 0.9469 - val_iou_score: 0.2520
# Epoch 165/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8017 - accuracy: 0.9873 - iou_score: 0.7114 - val_loss: 0.9820 - val_accuracy: 0.9483 - val_iou_score: 0.2550
# Epoch 166/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8014 - accuracy: 0.9874 - iou_score: 0.7105 - val_loss: 0.9824 - val_accuracy: 0.9474 - val_iou_score: 0.2492
# Epoch 167/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8015 - accuracy: 0.9874 - iou_score: 0.7103 - val_loss: 0.9799 - val_accuracy: 0.9469 - val_iou_score: 0.2467
# Epoch 168/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8011 - accuracy: 0.9874 - iou_score: 0.7127 - val_loss: 0.9816 - val_accuracy: 0.9448 - val_iou_score: 0.2466
# Epoch 169/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8011 - accuracy: 0.9875 - iou_score: 0.7137 - val_loss: 0.9828 - val_accuracy: 0.9463 - val_iou_score: 0.2522
# Epoch 170/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8014 - accuracy: 0.9874 - iou_score: 0.7123 - val_loss: 0.9847 - val_accuracy: 0.9481 - val_iou_score: 0.2550
# Epoch 171/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8018 - accuracy: 0.9874 - iou_score: 0.7112 - val_loss: 0.9824 - val_accuracy: 0.9486 - val_iou_score: 0.2520
# Epoch 172/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.8013 - accuracy: 0.9874 - iou_score: 0.7124 - val_loss: 0.9807 - val_accuracy: 0.9485 - val_iou_score: 0.2552
# Epoch 173/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8010 - accuracy: 0.9874 - iou_score: 0.7122 - val_loss: 0.9810 - val_accuracy: 0.9464 - val_iou_score: 0.2494
# Epoch 174/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8012 - accuracy: 0.9874 - iou_score: 0.7116 - val_loss: 0.9802 - val_accuracy: 0.9448 - val_iou_score: 0.2496
# Epoch 175/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8014 - accuracy: 0.9873 - iou_score: 0.7104 - val_loss: 0.9807 - val_accuracy: 0.9449 - val_iou_score: 0.2493
# Epoch 176/500
# 258/258 [==============================] - 131s 508ms/step - loss: 0.8009 - accuracy: 0.9875 - iou_score: 0.7173 - val_loss: 0.9808 - val_accuracy: 0.9465 - val_iou_score: 0.2548
# Epoch 177/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8005 - accuracy: 0.9875 - iou_score: 0.7156 - val_loss: 0.9819 - val_accuracy: 0.9470 - val_iou_score: 0.2519
# Epoch 178/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8003 - accuracy: 0.9877 - iou_score: 0.7174 - val_loss: 0.9825 - val_accuracy: 0.9479 - val_iou_score: 0.2549
# Epoch 179/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8001 - accuracy: 0.9878 - iou_score: 0.7168 - val_loss: 0.9817 - val_accuracy: 0.9476 - val_iou_score: 0.2491
# Epoch 180/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8001 - accuracy: 0.9877 - iou_score: 0.7163 - val_loss: 0.9832 - val_accuracy: 0.9459 - val_iou_score: 0.2460
# Epoch 181/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8002 - accuracy: 0.9877 - iou_score: 0.7160 - val_loss: 0.9832 - val_accuracy: 0.9462 - val_iou_score: 0.2518
# Epoch 182/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8002 - accuracy: 0.9878 - iou_score: 0.7184 - val_loss: 0.9818 - val_accuracy: 0.9458 - val_iou_score: 0.2492
# Epoch 183/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8001 - accuracy: 0.9879 - iou_score: 0.7195 - val_loss: 0.9816 - val_accuracy: 0.9469 - val_iou_score: 0.2521
# Epoch 184/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7999 - accuracy: 0.9879 - iou_score: 0.7181 - val_loss: 0.9831 - val_accuracy: 0.9466 - val_iou_score: 0.2519
# Epoch 185/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7999 - accuracy: 0.9879 - iou_score: 0.7179 - val_loss: 0.9807 - val_accuracy: 0.9474 - val_iou_score: 0.2494
# Epoch 186/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.8001 - accuracy: 0.9879 - iou_score: 0.7167 - val_loss: 0.9832 - val_accuracy: 0.9479 - val_iou_score: 0.2550
# Epoch 187/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.8005 - accuracy: 0.9878 - iou_score: 0.7157 - val_loss: 0.9825 - val_accuracy: 0.9472 - val_iou_score: 0.2549
# Epoch 188/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.7999 - accuracy: 0.9878 - iou_score: 0.7184 - val_loss: 0.9821 - val_accuracy: 0.9474 - val_iou_score: 0.2548
# Epoch 189/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.7993 - accuracy: 0.9880 - iou_score: 0.7214 - val_loss: 0.9812 - val_accuracy: 0.9460 - val_iou_score: 0.2520
# Epoch 190/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7991 - accuracy: 0.9882 - iou_score: 0.7249 - val_loss: 0.9809 - val_accuracy: 0.9459 - val_iou_score: 0.2520
# Epoch 191/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7992 - accuracy: 0.9881 - iou_score: 0.7213 - val_loss: 0.9802 - val_accuracy: 0.9460 - val_iou_score: 0.2461
# Epoch 192/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7993 - accuracy: 0.9879 - iou_score: 0.7205 - val_loss: 0.9826 - val_accuracy: 0.9466 - val_iou_score: 0.2464
# Epoch 193/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7994 - accuracy: 0.9879 - iou_score: 0.7227 - val_loss: 0.9836 - val_accuracy: 0.9480 - val_iou_score: 0.2519
# Epoch 194/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7997 - accuracy: 0.9879 - iou_score: 0.7187 - val_loss: 0.9844 - val_accuracy: 0.9486 - val_iou_score: 0.2521
# Epoch 195/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7994 - accuracy: 0.9880 - iou_score: 0.7211 - val_loss: 0.9837 - val_accuracy: 0.9486 - val_iou_score: 0.2522
# Epoch 196/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7987 - accuracy: 0.9882 - iou_score: 0.7265 - val_loss: 0.9825 - val_accuracy: 0.9481 - val_iou_score: 0.2522
# Epoch 197/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7987 - accuracy: 0.9882 - iou_score: 0.7237 - val_loss: 0.9818 - val_accuracy: 0.9461 - val_iou_score: 0.2520
# Epoch 198/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7988 - accuracy: 0.9883 - iou_score: 0.7237 - val_loss: 0.9808 - val_accuracy: 0.9445 - val_iou_score: 0.2463
# Epoch 199/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7991 - accuracy: 0.9881 - iou_score: 0.7223 - val_loss: 0.9833 - val_accuracy: 0.9475 - val_iou_score: 0.2519
# Epoch 200/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.8002 - accuracy: 0.9878 - iou_score: 0.7158 - val_loss: 0.9831 - val_accuracy: 0.9468 - val_iou_score: 0.2496
# Epoch 201/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7997 - accuracy: 0.9881 - iou_score: 0.7203 - val_loss: 0.9815 - val_accuracy: 0.9483 - val_iou_score: 0.2525
# Epoch 202/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7992 - accuracy: 0.9881 - iou_score: 0.7209 - val_loss: 0.9820 - val_accuracy: 0.9475 - val_iou_score: 0.2491
# Epoch 203/500
# 258/258 [==============================] - 131s 509ms/step - loss: 0.7988 - accuracy: 0.9882 - iou_score: 0.7240 - val_loss: 0.9811 - val_accuracy: 0.9462 - val_iou_score: 0.2490
# Epoch 204/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7981 - accuracy: 0.9884 - iou_score: 0.7267 - val_loss: 0.9812 - val_accuracy: 0.9469 - val_iou_score: 0.2464
# Epoch 205/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7978 - accuracy: 0.9885 - iou_score: 0.7282 - val_loss: 0.9818 - val_accuracy: 0.9464 - val_iou_score: 0.2520
# Epoch 206/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7982 - accuracy: 0.9884 - iou_score: 0.7294 - val_loss: 0.9821 - val_accuracy: 0.9469 - val_iou_score: 0.2492
# Epoch 207/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7984 - accuracy: 0.9883 - iou_score: 0.7250 - val_loss: 0.9825 - val_accuracy: 0.9472 - val_iou_score: 0.2494
# Epoch 208/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.7988 - accuracy: 0.9882 - iou_score: 0.7228 - val_loss: 0.9842 - val_accuracy: 0.9475 - val_iou_score: 0.2492
# Epoch 209/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7988 - accuracy: 0.9882 - iou_score: 0.7234 - val_loss: 0.9846 - val_accuracy: 0.9493 - val_iou_score: 0.2551
# Epoch 210/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7978 - accuracy: 0.9884 - iou_score: 0.7296 - val_loss: 0.9842 - val_accuracy: 0.9487 - val_iou_score: 0.2523
# Epoch 211/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7976 - accuracy: 0.9885 - iou_score: 0.7290 - val_loss: 0.9851 - val_accuracy: 0.9486 - val_iou_score: 0.2522
# Epoch 212/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7974 - accuracy: 0.9886 - iou_score: 0.7317 - val_loss: 0.9842 - val_accuracy: 0.9468 - val_iou_score: 0.2519
# Epoch 213/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7977 - accuracy: 0.9886 - iou_score: 0.7313 - val_loss: 0.9829 - val_accuracy: 0.9454 - val_iou_score: 0.2492
# Epoch 214/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7978 - accuracy: 0.9884 - iou_score: 0.7273 - val_loss: 0.9826 - val_accuracy: 0.9481 - val_iou_score: 0.2493
# Epoch 215/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7983 - accuracy: 0.9884 - iou_score: 0.7266 - val_loss: 0.9821 - val_accuracy: 0.9478 - val_iou_score: 0.2522
# Epoch 216/500
# 258/258 [==============================] - 132s 510ms/step - loss: 0.7986 - accuracy: 0.9883 - iou_score: 0.7247 - val_loss: 0.9821 - val_accuracy: 0.9467 - val_iou_score: 0.2497
# Epoch 217/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7978 - accuracy: 0.9885 - iou_score: 0.7280 - val_loss: 0.9813 - val_accuracy: 0.9461 - val_iou_score: 0.2520
# Epoch 218/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7972 - accuracy: 0.9887 - iou_score: 0.7331 - val_loss: 0.9823 - val_accuracy: 0.9470 - val_iou_score: 0.2522
# Epoch 219/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7971 - accuracy: 0.9888 - iou_score: 0.7326 - val_loss: 0.9814 - val_accuracy: 0.9471 - val_iou_score: 0.2520
# Epoch 220/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7970 - accuracy: 0.9887 - iou_score: 0.7336 - val_loss: 0.9833 - val_accuracy: 0.9481 - val_iou_score: 0.2522
# Epoch 221/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7970 - accuracy: 0.9888 - iou_score: 0.7324 - val_loss: 0.9830 - val_accuracy: 0.9472 - val_iou_score: 0.2519
# Epoch 222/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7972 - accuracy: 0.9888 - iou_score: 0.7306 - val_loss: 0.9833 - val_accuracy: 0.9470 - val_iou_score: 0.2522
# Epoch 223/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7977 - accuracy: 0.9887 - iou_score: 0.7306 - val_loss: 0.9831 - val_accuracy: 0.9479 - val_iou_score: 0.2521
# Epoch 224/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7975 - accuracy: 0.9887 - iou_score: 0.7289 - val_loss: 0.9839 - val_accuracy: 0.9486 - val_iou_score: 0.2524
# Epoch 225/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7973 - accuracy: 0.9887 - iou_score: 0.7314 - val_loss: 0.9851 - val_accuracy: 0.9474 - val_iou_score: 0.2521
# Epoch 226/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7971 - accuracy: 0.9888 - iou_score: 0.7340 - val_loss: 0.9845 - val_accuracy: 0.9473 - val_iou_score: 0.2520
# Epoch 227/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7976 - accuracy: 0.9887 - iou_score: 0.7315 - val_loss: 0.9822 - val_accuracy: 0.9477 - val_iou_score: 0.2523
# Epoch 228/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7972 - accuracy: 0.9888 - iou_score: 0.7309 - val_loss: 0.9837 - val_accuracy: 0.9487 - val_iou_score: 0.2525
# Epoch 229/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7967 - accuracy: 0.9889 - iou_score: 0.7344 - val_loss: 0.9817 - val_accuracy: 0.9456 - val_iou_score: 0.2496
# Epoch 230/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7965 - accuracy: 0.9889 - iou_score: 0.7343 - val_loss: 0.9817 - val_accuracy: 0.9447 - val_iou_score: 0.2496
# Epoch 231/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7966 - accuracy: 0.9889 - iou_score: 0.7337 - val_loss: 0.9820 - val_accuracy: 0.9432 - val_iou_score: 0.2441
# Epoch 232/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7964 - accuracy: 0.9890 - iou_score: 0.7378 - val_loss: 0.9816 - val_accuracy: 0.9456 - val_iou_score: 0.2467
# Epoch 233/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.7965 - accuracy: 0.9889 - iou_score: 0.7352 - val_loss: 0.9815 - val_accuracy: 0.9475 - val_iou_score: 0.2494
# Epoch 234/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7962 - accuracy: 0.9889 - iou_score: 0.7365 - val_loss: 0.9835 - val_accuracy: 0.9484 - val_iou_score: 0.2521
# Epoch 235/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7966 - accuracy: 0.9889 - iou_score: 0.7358 - val_loss: 0.9833 - val_accuracy: 0.9476 - val_iou_score: 0.2490
# Epoch 236/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7971 - accuracy: 0.9888 - iou_score: 0.7322 - val_loss: 0.9843 - val_accuracy: 0.9476 - val_iou_score: 0.2520
# Epoch 237/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7966 - accuracy: 0.9890 - iou_score: 0.7376 - val_loss: 0.9840 - val_accuracy: 0.9479 - val_iou_score: 0.2549
# Epoch 238/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7969 - accuracy: 0.9889 - iou_score: 0.7341 - val_loss: 0.9837 - val_accuracy: 0.9472 - val_iou_score: 0.2463
# Epoch 239/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7966 - accuracy: 0.9890 - iou_score: 0.7348 - val_loss: 0.9835 - val_accuracy: 0.9484 - val_iou_score: 0.2522
# Epoch 240/500
# 258/258 [==============================] - 132s 511ms/step - loss: 0.7969 - accuracy: 0.9889 - iou_score: 0.7332 - val_loss: 0.9833 - val_accuracy: 0.9479 - val_iou_score: 0.2493
# Epoch 241/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7970 - accuracy: 0.9889 - iou_score: 0.7329 - val_loss: 0.9823 - val_accuracy: 0.9463 - val_iou_score: 0.2439
# Epoch 242/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.7967 - accuracy: 0.9889 - iou_score: 0.7343 - val_loss: 0.9832 - val_accuracy: 0.9471 - val_iou_score: 0.2521
# Epoch 243/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7955 - accuracy: 0.9893 - iou_score: 0.7405 - val_loss: 0.9840 - val_accuracy: 0.9463 - val_iou_score: 0.2523
# Epoch 244/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7948 - accuracy: 0.9894 - iou_score: 0.7489 - val_loss: 0.9824 - val_accuracy: 0.9470 - val_iou_score: 0.2520
# Epoch 245/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7951 - accuracy: 0.9893 - iou_score: 0.7439 - val_loss: 0.9825 - val_accuracy: 0.9479 - val_iou_score: 0.2522
# Epoch 246/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7957 - accuracy: 0.9891 - iou_score: 0.7410 - val_loss: 0.9841 - val_accuracy: 0.9450 - val_iou_score: 0.2463
# Epoch 247/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7957 - accuracy: 0.9891 - iou_score: 0.7409 - val_loss: 0.9833 - val_accuracy: 0.9474 - val_iou_score: 0.2529
# Epoch 248/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7963 - accuracy: 0.9889 - iou_score: 0.7384 - val_loss: 0.9841 - val_accuracy: 0.9488 - val_iou_score: 0.2523
# Epoch 249/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7959 - accuracy: 0.9891 - iou_score: 0.7401 - val_loss: 0.9833 - val_accuracy: 0.9478 - val_iou_score: 0.2548
# Epoch 250/500
# ...
# Epoch 419/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.7880 - accuracy: 0.9914 - iou_score: 0.7782 - val_loss: 0.9855 - val_accuracy: 0.9463 - val_iou_score: 0.2464
# Epoch 420/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7884 - accuracy: 0.9913 - iou_score: 0.7771 - val_loss: 0.9848 - val_accuracy: 0.9458 - val_iou_score: 0.2464
# Epoch 421/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.7887 - accuracy: 0.9912 - iou_score: 0.7753 - val_loss: 0.9856 - val_accuracy: 0.9471 - val_iou_score: 0.2466
# Epoch 422/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.7890 - accuracy: 0.9911 - iou_score: 0.7747 - val_loss: 0.9869 - val_accuracy: 0.9476 - val_iou_score: 0.2467
# Epoch 423/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7887 - accuracy: 0.9912 - iou_score: 0.7764 - val_loss: 0.9871 - val_accuracy: 0.9480 - val_iou_score: 0.2493
# Epoch 424/500
# 258/258 [==============================] - 133s 517ms/step - loss: 0.7883 - accuracy: 0.9913 - iou_score: 0.7783 - val_loss: 0.9870 - val_accuracy: 0.9484 - val_iou_score: 0.2522
# Epoch 425/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7885 - accuracy: 0.9913 - iou_score: 0.7768 - val_loss: 0.9853 - val_accuracy: 0.9471 - val_iou_score: 0.2522
# Epoch 426/500
# 258/258 [==============================] - 133s 518ms/step - loss: 0.7891 - accuracy: 0.9912 - iou_score: 0.7756 - val_loss: 0.9847 - val_accuracy: 0.9461 - val_iou_score: 0.2465
# Epoch 427/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7885 - accuracy: 0.9913 - iou_score: 0.7787 - val_loss: 0.9853 - val_accuracy: 0.9441 - val_iou_score: 0.2469
# Epoch 428/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7883 - accuracy: 0.9914 - iou_score: 0.7807 - val_loss: 0.9863 - val_accuracy: 0.9465 - val_iou_score: 0.2493
# Epoch 429/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7881 - accuracy: 0.9915 - iou_score: 0.7825 - val_loss: 0.9861 - val_accuracy: 0.9471 - val_iou_score: 0.2465
# Epoch 430/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7879 - accuracy: 0.9915 - iou_score: 0.7854 - val_loss: 0.9860 - val_accuracy: 0.9477 - val_iou_score: 0.2494
# Epoch 431/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7879 - accuracy: 0.9915 - iou_score: 0.7806 - val_loss: 0.9859 - val_accuracy: 0.9475 - val_iou_score: 0.2492
# Epoch 432/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7882 - accuracy: 0.9914 - iou_score: 0.7780 - val_loss: 0.9853 - val_accuracy: 0.9473 - val_iou_score: 0.2496
# Epoch 433/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7881 - accuracy: 0.9914 - iou_score: 0.7786 - val_loss: 0.9849 - val_accuracy: 0.9475 - val_iou_score: 0.2525
# Epoch 434/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7881 - accuracy: 0.9914 - iou_score: 0.7816 - val_loss: 0.9873 - val_accuracy: 0.9470 - val_iou_score: 0.2520
# Epoch 435/500
# 258/258 [==============================] - 133s 517ms/step - loss: 0.7880 - accuracy: 0.9914 - iou_score: 0.7812 - val_loss: 0.9860 - val_accuracy: 0.9459 - val_iou_score: 0.2496
# Epoch 436/500
# 258/258 [==============================] - 133s 517ms/step - loss: 0.7884 - accuracy: 0.9914 - iou_score: 0.7785 - val_loss: 0.9858 - val_accuracy: 0.9469 - val_iou_score: 0.2466
# Epoch 437/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7886 - accuracy: 0.9913 - iou_score: 0.7782 - val_loss: 0.9863 - val_accuracy: 0.9478 - val_iou_score: 0.2524
# Epoch 438/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7882 - accuracy: 0.9914 - iou_score: 0.7792 - val_loss: 0.9869 - val_accuracy: 0.9477 - val_iou_score: 0.2523
# Epoch 439/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7874 - accuracy: 0.9916 - iou_score: 0.7841 - val_loss: 0.9866 - val_accuracy: 0.9467 - val_iou_score: 0.2522
# Epoch 440/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.7874 - accuracy: 0.9916 - iou_score: 0.7855 - val_loss: 0.9865 - val_accuracy: 0.9462 - val_iou_score: 0.2521
# Epoch 441/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7877 - accuracy: 0.9915 - iou_score: 0.7821 - val_loss: 0.9865 - val_accuracy: 0.9474 - val_iou_score: 0.2551
# Epoch 442/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7876 - accuracy: 0.9915 - iou_score: 0.7845 - val_loss: 0.9860 - val_accuracy: 0.9480 - val_iou_score: 0.2521
# Epoch 443/500
# 258/258 [==============================] - 132s 513ms/step - loss: 0.7876 - accuracy: 0.9916 - iou_score: 0.7831 - val_loss: 0.9864 - val_accuracy: 0.9478 - val_iou_score: 0.2491
# Epoch 444/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7878 - accuracy: 0.9916 - iou_score: 0.7815 - val_loss: 0.9870 - val_accuracy: 0.9479 - val_iou_score: 0.2549
# Epoch 445/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7875 - accuracy: 0.9916 - iou_score: 0.7826 - val_loss: 0.9864 - val_accuracy: 0.9468 - val_iou_score: 0.2464
# Epoch 446/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7874 - accuracy: 0.9916 - iou_score: 0.7842 - val_loss: 0.9863 - val_accuracy: 0.9469 - val_iou_score: 0.2522
# Epoch 447/500
# 258/258 [==============================] - 133s 517ms/step - loss: 0.7873 - accuracy: 0.9917 - iou_score: 0.7831 - val_loss: 0.9862 - val_accuracy: 0.9469 - val_iou_score: 0.2493
# Epoch 448/500
# 258/258 [==============================] - 133s 517ms/step - loss: 0.7874 - accuracy: 0.9916 - iou_score: 0.7837 - val_loss: 0.9868 - val_accuracy: 0.9473 - val_iou_score: 0.2523
# Epoch 449/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7876 - accuracy: 0.9916 - iou_score: 0.7832 - val_loss: 0.9867 - val_accuracy: 0.9470 - val_iou_score: 0.2520
# Epoch 450/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7875 - accuracy: 0.9916 - iou_score: 0.7847 - val_loss: 0.9853 - val_accuracy: 0.9459 - val_iou_score: 0.2494
# Epoch 451/500
# 258/258 [==============================] - 133s 517ms/step - loss: 0.7875 - accuracy: 0.9916 - iou_score: 0.7835 - val_loss: 0.9856 - val_accuracy: 0.9474 - val_iou_score: 0.2521
# Epoch 452/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7877 - accuracy: 0.9916 - iou_score: 0.7817 - val_loss: 0.9863 - val_accuracy: 0.9476 - val_iou_score: 0.2491
# Epoch 453/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7875 - accuracy: 0.9916 - iou_score: 0.7820 - val_loss: 0.9858 - val_accuracy: 0.9466 - val_iou_score: 0.2521
# Epoch 454/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7874 - accuracy: 0.9916 - iou_score: 0.7826 - val_loss: 0.9865 - val_accuracy: 0.9460 - val_iou_score: 0.2493
# Epoch 455/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7876 - accuracy: 0.9915 - iou_score: 0.7852 - val_loss: 0.9865 - val_accuracy: 0.9473 - val_iou_score: 0.2493
# Epoch 456/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7879 - accuracy: 0.9914 - iou_score: 0.7795 - val_loss: 0.9873 - val_accuracy: 0.9480 - val_iou_score: 0.2493
# Epoch 457/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7876 - accuracy: 0.9915 - iou_score: 0.7850 - val_loss: 0.9872 - val_accuracy: 0.9484 - val_iou_score: 0.2494
# Epoch 458/500
# 258/258 [==============================] - 133s 517ms/step - loss: 0.7877 - accuracy: 0.9916 - iou_score: 0.7838 - val_loss: 0.9864 - val_accuracy: 0.9476 - val_iou_score: 0.2493
# Epoch 459/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7876 - accuracy: 0.9915 - iou_score: 0.7811 - val_loss: 0.9853 - val_accuracy: 0.9457 - val_iou_score: 0.2525
# Epoch 460/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7880 - accuracy: 0.9914 - iou_score: 0.7810 - val_loss: 0.9855 - val_accuracy: 0.9467 - val_iou_score: 0.2494
# Epoch 461/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7874 - accuracy: 0.9916 - iou_score: 0.7845 - val_loss: 0.9853 - val_accuracy: 0.9441 - val_iou_score: 0.2467
# Epoch 462/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7870 - accuracy: 0.9917 - iou_score: 0.7878 - val_loss: 0.9858 - val_accuracy: 0.9450 - val_iou_score: 0.2554
# Epoch 463/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7869 - accuracy: 0.9917 - iou_score: 0.7871 - val_loss: 0.9870 - val_accuracy: 0.9457 - val_iou_score: 0.2465
# Epoch 464/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7871 - accuracy: 0.9917 - iou_score: 0.7849 - val_loss: 0.9869 - val_accuracy: 0.9477 - val_iou_score: 0.2493
# Epoch 465/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7869 - accuracy: 0.9917 - iou_score: 0.7848 - val_loss: 0.9862 - val_accuracy: 0.9478 - val_iou_score: 0.2493
# Epoch 466/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7874 - accuracy: 0.9917 - iou_score: 0.7825 - val_loss: 0.9863 - val_accuracy: 0.9475 - val_iou_score: 0.2494
# Epoch 467/500
# 258/258 [==============================] - 134s 518ms/step - loss: 0.7875 - accuracy: 0.9916 - iou_score: 0.7830 - val_loss: 0.9870 - val_accuracy: 0.9474 - val_iou_score: 0.2522
# Epoch 468/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7870 - accuracy: 0.9917 - iou_score: 0.7854 - val_loss: 0.9865 - val_accuracy: 0.9473 - val_iou_score: 0.2491
# Epoch 469/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7867 - accuracy: 0.9918 - iou_score: 0.7869 - val_loss: 0.9856 - val_accuracy: 0.9465 - val_iou_score: 0.2471
# Epoch 470/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7868 - accuracy: 0.9918 - iou_score: 0.7865 - val_loss: 0.9867 - val_accuracy: 0.9475 - val_iou_score: 0.2494
# Epoch 471/500
# 258/258 [==============================] - 133s 517ms/step - loss: 0.7867 - accuracy: 0.9919 - iou_score: 0.7852 - val_loss: 0.9865 - val_accuracy: 0.9472 - val_iou_score: 0.2492
# Epoch 472/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7868 - accuracy: 0.9919 - iou_score: 0.7858 - val_loss: 0.9868 - val_accuracy: 0.9473 - val_iou_score: 0.2493
# Epoch 473/500
# 258/258 [==============================] - 133s 517ms/step - loss: 0.7868 - accuracy: 0.9918 - iou_score: 0.7855 - val_loss: 0.9867 - val_accuracy: 0.9468 - val_iou_score: 0.2493
# Epoch 474/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7868 - accuracy: 0.9918 - iou_score: 0.7857 - val_loss: 0.9861 - val_accuracy: 0.9462 - val_iou_score: 0.2494
# Epoch 475/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7868 - accuracy: 0.9918 - iou_score: 0.7877 - val_loss: 0.9863 - val_accuracy: 0.9472 - val_iou_score: 0.2521
# Epoch 476/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7866 - accuracy: 0.9919 - iou_score: 0.7874 - val_loss: 0.9852 - val_accuracy: 0.9466 - val_iou_score: 0.2494
# Epoch 477/500
# 258/258 [==============================] - 132s 514ms/step - loss: 0.7868 - accuracy: 0.9918 - iou_score: 0.7863 - val_loss: 0.9856 - val_accuracy: 0.9463 - val_iou_score: 0.2465
# Epoch 478/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.7870 - accuracy: 0.9917 - iou_score: 0.7854 - val_loss: 0.9857 - val_accuracy: 0.9464 - val_iou_score: 0.2464
# Epoch 479/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.7871 - accuracy: 0.9917 - iou_score: 0.7827 - val_loss: 0.9857 - val_accuracy: 0.9466 - val_iou_score: 0.2496
# Epoch 480/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7867 - accuracy: 0.9918 - iou_score: 0.7869 - val_loss: 0.9865 - val_accuracy: 0.9469 - val_iou_score: 0.2493
# Epoch 481/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.7869 - accuracy: 0.9917 - iou_score: 0.7869 - val_loss: 0.9868 - val_accuracy: 0.9472 - val_iou_score: 0.2465
# Epoch 482/500
# 258/258 [==============================] - 132s 512ms/step - loss: 0.7867 - accuracy: 0.9918 - iou_score: 0.7882 - val_loss: 0.9869 - val_accuracy: 0.9474 - val_iou_score: 0.2523
# Epoch 483/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7864 - accuracy: 0.9919 - iou_score: 0.7888 - val_loss: 0.9876 - val_accuracy: 0.9485 - val_iou_score: 0.2550
# Epoch 484/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7867 - accuracy: 0.9919 - iou_score: 0.7884 - val_loss: 0.9869 - val_accuracy: 0.9485 - val_iou_score: 0.2521
# Epoch 485/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7865 - accuracy: 0.9919 - iou_score: 0.7875 - val_loss: 0.9868 - val_accuracy: 0.9488 - val_iou_score: 0.2521
# Epoch 486/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7865 - accuracy: 0.9918 - iou_score: 0.7880 - val_loss: 0.9872 - val_accuracy: 0.9482 - val_iou_score: 0.2551
# Epoch 487/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7867 - accuracy: 0.9918 - iou_score: 0.7859 - val_loss: 0.9869 - val_accuracy: 0.9470 - val_iou_score: 0.2464
# Epoch 488/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7866 - accuracy: 0.9918 - iou_score: 0.7854 - val_loss: 0.9864 - val_accuracy: 0.9452 - val_iou_score: 0.2468
# Epoch 489/500
# 258/258 [==============================] - 133s 517ms/step - loss: 0.7868 - accuracy: 0.9918 - iou_score: 0.7875 - val_loss: 0.9864 - val_accuracy: 0.9467 - val_iou_score: 0.2495
# Epoch 490/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7868 - accuracy: 0.9918 - iou_score: 0.7876 - val_loss: 0.9866 - val_accuracy: 0.9463 - val_iou_score: 0.2498
# Epoch 491/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7869 - accuracy: 0.9918 - iou_score: 0.7861 - val_loss: 0.9866 - val_accuracy: 0.9467 - val_iou_score: 0.2525
# Epoch 492/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7871 - accuracy: 0.9918 - iou_score: 0.7848 - val_loss: 0.9856 - val_accuracy: 0.9470 - val_iou_score: 0.2492
# Epoch 493/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7875 - accuracy: 0.9916 - iou_score: 0.7808 - val_loss: 0.9867 - val_accuracy: 0.9477 - val_iou_score: 0.2493
# Epoch 494/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7864 - accuracy: 0.9919 - iou_score: 0.7878 - val_loss: 0.9860 - val_accuracy: 0.9466 - val_iou_score: 0.2525
# Epoch 495/500
# 258/258 [==============================] - 133s 514ms/step - loss: 0.7859 - accuracy: 0.9920 - iou_score: 0.7936 - val_loss: 0.9866 - val_accuracy: 0.9467 - val_iou_score: 0.2526
# Epoch 496/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7860 - accuracy: 0.9921 - iou_score: 0.7922 - val_loss: 0.9869 - val_accuracy: 0.9480 - val_iou_score: 0.2550
# Epoch 497/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7862 - accuracy: 0.9920 - iou_score: 0.7895 - val_loss: 0.9873 - val_accuracy: 0.9477 - val_iou_score: 0.2496
# Epoch 498/500
# 258/258 [==============================] - 133s 516ms/step - loss: 0.7864 - accuracy: 0.9919 - iou_score: 0.7887 - val_loss: 0.9874 - val_accuracy: 0.9483 - val_iou_score: 0.2524
# Epoch 499/500
# 258/258 [==============================] - 133s 515ms/step - loss: 0.7862 - accuracy: 0.9920 - iou_score: 0.7879 - val_loss: 0.9871 - val_accuracy: 0.9478 - val_iou_score: 0.2494
# Epoch 500/500
# 258/258 [==============================] - 133s 517ms/step - loss: 0.7861 - accuracy: 0.9920 - iou_score: 0.7904 - val_loss: 0.9861 - val_accuracy: 0.9468 - val_iou_score: 0.2493

# %%
#import tensorflow as tf
#for gpu in tf.config.list_physical_devices("GPU")
    #tf.config.experimental.set_memory_growth(gpu, True)

# %%
model.save('brats_3d_new.hdf5')

# %%
history

# %%
#plot the training and validation IoU and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('t')
plt.show()
plt.close()

# %%
from matplotlib import pyplot as plt

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('tr_acc')
plt.show()
plt.close()

# %%
plt.savefig('tr_loss_acc.png')

# %%
model = model_from_json(open(modelFile).read())
model.load_weights(os.path.join(os.path.dirname(modelFile), 'model_weights.h5'))

# %%
from keras.models import load_model


#Load model for prediction or continue training

#For continuing training....
#The following gives an error: Unknown loss function: dice_loss_plus_1focal_loss
#This is because the model does not save loss function and metrics. So to compile and 
#continue training we need to provide these as custom_objects.
#my_model = load_model('brats_3d.hdf5')

#So let us add the loss as custom object... but the following throws another error...
#Unknown metric function: iou_score
#my_model = load_model('brats_3d.hdf5', custom_objects={'dice_loss_plus_1focal_loss': total_loss})

#Now, let us add the iou_score function we used during our initial training
my_model = load_model('brats_3d_new.hdf5', 
                      custom_objects={'dice_loss_plus_1focal_loss': total_loss,
                                      'iou_score':sm.metrics.IOUScore(threshold=0.5)})

#Now all set to continue the training process. 
history2=my_model.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=1,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )

# %%
my_model = load_model('brats_3d.hdf5', 
                      compile=False)


#Verify IoU on a batch of images from the test dataset
#Using built in keras function for IoU
#Only works on TF > 2.0
from keras.metrics import MeanIoU

batch_size=8 #Check IoU for a batch of images
test_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
test_image_batch, test_mask_batch = test_img_datagen.__next__()

test_mask_batch_argmax = np.argmax(test_mask_batch, axis=4)
test_pred_batch = my_model.predict(test_image_batch)
test_pred_batch_argmax = np.argmax(test_pred_batch, axis=4)

n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(test_pred_batch_argmax, test_mask_batch_argmax)
print("Mean IoU =", IOU_keras.result().numpy())

# %%
#Predict on a few test images, one at a time
#Try images: 
img_num = 82

test_img = np.load("/home/passion/Documents/dockerfiles/brats_split_75-25/val/images/image_"+str(img_num)+".npy")

test_mask = np.load("/home/passion/Documents/dockerfiles/brats_split_75-25/val/masks/mask_"+str(img_num)+".npy")
test_mask_argmax=np.argmax(test_mask, axis=3)

test_img_input = np.expand_dims(test_img, axis=0)
test_prediction = my_model.predict(test_img_input)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]


# print(test_prediction_argmax.shape)
# print(test_mask_argmax.shape)
# print(np.unique(test_prediction_argmax))

# %%
from matplotlib import pyplot as plt
import random

#n_slice=random.randint(0, test_prediction_argmax.shape[2])
n_slice = 55
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,n_slice,1], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,n_slice])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:, n_slice])
plt.show()

# %%
import numpy as np
from keras import backend as K
from keras.engine import Input, Model
from keras.layers import Conv3D, MaxPooling3D, UpSampling3D, Activation, BatchNormalization, PReLU, Deconvolution3D
from keras.optimizers import Adam

from unet3d.metrics import dice_coefficient_loss, get_label_dice_coefficient_function, dice_coefficient

K.set_image_data_format("channels_first")

try:
    from keras.engine import merge
except ImportError:
    from keras.layers.merge import concatenate


def unet_model_3d(input_shape, pool_size=(2, 2, 2), n_labels=1, initial_learning_rate=0.00001, deconvolution=False,
                  depth=4, n_base_filters=32, include_label_wise_dice_coefficients=False, metrics=dice_coefficient,
                  batch_normalization=False, activation_name="sigmoid"):
    """
    Builds the 3D UNet Keras model.f
    :param metrics: List metrics to be calculated during model training (default is dice coefficient).
    :param include_label_wise_dice_coefficients: If True and n_labels is greater than 1, model will report the dice
    coefficient for each label as metric.
    :param n_base_filters: The number of filters that the first layer in the convolution network will have. Following
    layers will contain a multiple of this number. Lowering this number will likely reduce the amount of memory required
    to train the model.
    :param depth: indicates the depth of the U-shape for the model. The greater the depth, the more max pooling
    layers will be added to the model. Lowering the depth may reduce the amount of memory required for training.
    :param input_shape: Shape of the input data (n_chanels, x_size, y_size, z_size). The x, y, and z sizes must be
    divisible by the pool size to the power of the depth of the UNet, that is pool_size^depth.
    :param pool_size: Pool size for the max pooling operations.
    :param n_labels: Number of binary labels that the model is learning.
    :param initial_learning_rate: Initial learning rate for the model. This will be decayed during training.
    :param deconvolution: If set to True, will use transpose convolution(deconvolution) instead of up-sampling. This
    increases the amount memory required during training.
    :return: Untrained 3D UNet Model
    """
    inputs = Input(input_shape)
    current_layer = inputs
    levels = list()

    # add levels with max pooling
    for layer_depth in range(depth):
        layer1 = create_convolution_block(input_layer=current_layer, n_filters=n_base_filters*(2**layer_depth),
                                          batch_normalization=batch_normalization)
        layer2 = create_convolution_block(input_layer=layer1, n_filters=n_base_filters*(2**layer_depth)*2,
                                          batch_normalization=batch_normalization)
        if layer_depth < depth - 1:
            current_layer = MaxPooling3D(pool_size=pool_size)(layer2)
            levels.append([layer1, layer2, current_layer])
        else:
            current_layer = layer2
            levels.append([layer1, layer2])

    # add levels with up-convolution or up-sampling
    for layer_depth in range(depth-2, -1, -1):
        up_convolution = get_up_convolution(pool_size=pool_size, deconvolution=deconvolution,
                                            n_filters=current_layer._keras_shape[1])(current_layer)
        concat = concatenate([up_convolution, levels[layer_depth][1]], axis=1)
        current_layer = create_convolution_block(n_filters=levels[layer_depth][1]._keras_shape[1],
                                                 input_layer=concat, batch_normalization=batch_normalization)
        current_layer = create_convolution_block(n_filters=levels[layer_depth][1]._keras_shape[1],
                                                 input_layer=current_layer,
                                                 batch_normalization=batch_normalization)

    final_convolution = Conv3D(n_labels, (1, 1, 1))(current_layer)
    act = Activation(activation_name)(final_convolution)
    model = Model(inputs=inputs, outputs=act)

    if not isinstance(metrics, list):
        metrics = [metrics]

    if include_label_wise_dice_coefficients and n_labels > 1:
        label_wise_dice_metrics = [get_label_dice_coefficient_function(index) for index in range(n_labels)]
        if metrics:
            metrics = metrics + label_wise_dice_metrics
        else:
            metrics = label_wise_dice_metrics

    model.compile(optimizer=Adam(lr=initial_learning_rate), loss=dice_coefficient_loss, metrics=metrics)
    return model


def create_convolution_block(input_layer, n_filters, batch_normalization=False, kernel=(3, 3, 3), activation=None,
                             padding='same', strides=(1, 1, 1), instance_normalization=False):
    """
    :param strides:
    :param input_layer:
    :param n_filters:
    :param batch_normalization:
    :param kernel:
    :param activation: Keras activation layer to use. (default is 'relu')
    :param padding:
    :return:
    """
    layer = Conv3D(n_filters, kernel, padding=padding, strides=strides)(input_layer)
    if batch_normalization:
        layer = BatchNormalization(axis=1)(layer)
    elif instance_normalization:
        try:
            from keras_contrib.layers.normalization import InstanceNormalization
        except ImportError:
            raise ImportError("Install keras_contrib in order to use instance normalization."
                              "\nTry: pip install git+https://www.github.com/farizrahman4u/keras-contrib.git")
        layer = InstanceNormalization(axis=1)(layer)
    if activation is None:
        return Activation('relu')(layer)
    else:
        return activation()(layer)


def compute_level_output_shape(n_filters, depth, pool_size, image_shape):
    """
    Each level has a particular output shape based on the number of filters used in that level and the depth or number 
    of max pooling operations that have been done on the data at that point.
    :param image_shape: shape of the 3d image.
    :param pool_size: the pool_size parameter used in the max pooling operation.
    :param n_filters: Number of filters used by the last node in a given level.
    :param depth: The number of levels down in the U-shaped model a given node is.
    :return: 5D vector of the shape of the output node 
    """
    output_image_shape = np.asarray(np.divide(image_shape, np.power(pool_size, depth)), dtype=np.int32).tolist()
    return tuple([None, n_filters] + output_image_shape)


def get_up_convolution(n_filters, pool_size, kernel_size=(2, 2, 2), strides=(2, 2, 2),
                       deconvolution=False):
    if deconvolution:
        return Deconvolution3D(filters=n_filters, kernel_size=kernel_size,
                               strides=strides)
    else:
        return UpSampling3D(size=pool_size)
